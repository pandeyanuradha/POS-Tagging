# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
import random
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
from sklearn_crfsuite import CRF
from sklearn_crfsuite import metrics
from sklearn_crfsuite import scorers
from collections import Counter

# %%
tagged_sentence = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
tagged_sentence[:2]
# Out:
# [[('Pierre', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   (',', '.'),
#   ('61', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('join', 'VERB'),
#   ('the', 'DET'),
#   ('board', 'NOUN'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('nonexecutive', 'ADJ'),
#   ('director', 'NOUN'),
#   ('Nov.', 'NOUN'),
#   ('29', 'NUM'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   ('is', 'VERB'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('Elsevier', 'NOUN'),
#   ('N.V.', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Dutch', 'NOUN'),
#   ('publishing', 'VERB'),
#   ('group', 'NOUN'),
#   ('.', '.')]]

# %%
print("Total Number of Tagged sentences", len(tagged_sentence))
# Out:
# Total Number of Tagged sentences 3914

# %%
train_set,test_set =train_test_split(tagged_sentence,train_size=0.80,random_state=101)

# %%
train_set
# Out:
# [[('Drink', 'NOUN'),
#   ('Carrier', 'NOUN'),
#   ('Competes', 'VERB'),
#   ('With', 'ADP'),
#   ('Cartons', 'NOUN')],
#  [('At', 'ADP'),
#   ('last', 'ADJ'),
#   ('count', 'NOUN'),
#   (',', '.'),
#   ('Candela', 'NOUN'),
#   ('had', 'VERB'),
#   ('sold', 'VERB'),
#   ('$', '.'),
#   ('4', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('of', 'ADP'),
#   ('its', 'PRON'),
#   ('medical', 'ADJ'),
#   ('devices', 'NOUN'),
#   ('in', 'ADP'),
#   ('Japan', 'NOUN'),
#   ('.', '.')],
#  [('Mrs.', 'NOUN'),
#   ('Hills', 'NOUN'),
#   ('lauded', 'VERB'),
#   ('South', 'NOUN'),
#   ('Korea', 'NOUN'),
#   ('for', 'ADP'),
#   ('*-1', 'X'),
#   ('creating', 'VERB'),
#   ('an', 'DET'),
#   ('intellectual-property', 'ADJ'),
#   ('task', 'NOUN'),
#   ('force', 'NOUN'),
#   ('and', 'CONJ'),
#   ('special', 'ADJ'),
#   ('enforcement', 'NOUN'),
#   ('teams', 'NOUN'),
#   ('of', 'ADP'),
#   ('police', 'NOUN'),
#   ('officers', 'NOUN'),
#   ('and', 'CONJ'),
#   ('prosecutors', 'NOUN'),
#   ('trained', 'VERB'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('pursue', 'VERB'),
#   ('movie', 'NOUN'),
#   ('and', 'CONJ'),
#   ('book', 'NOUN'),
#   ('pirates', 'NOUN'),
#   ('.', '.')],
#  [('Section', 'NOUN'),
#   ('501', 'NUM'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('United', 'NOUN'),
#   ('States', 'NOUN'),
#   ('Information', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Educational', 'NOUN'),
#   ('Exchange', 'NOUN'),
#   ('Act', 'NOUN'),
#   ('of', 'ADP'),
#   ('1948', 'NUM'),
#   ('says', 'VERB'),
#   ('0', 'X'),
#   ('Voice', 'NOUN'),
#   ('material', 'NOUN'),
#   ('shall', 'VERB'),
#   ('be', 'VERB'),
#   ('available', 'ADJ'),
#   ('to', 'PRT'),
#   ('certain', 'ADJ'),
#   ('of', 'ADP'),
#   ('us', 'PRON'),
#   ('-LRB-', '.'),
#   ('but', 'CONJ'),
#   ('now', 'ADV'),
#   (',', '.'),
#   ('thanks', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('USIA', 'NOUN'),
#   ("'s", 'PRT'),
#   ('new', 'ADJ'),
#   ('position', 'NOUN'),
#   (',', '.'),
#   ('all', 'DET'),
#   ('of', 'ADP'),
#   ('us', 'PRON'),
#   ('-RRB-', '.'),
#   ('``', '.'),
#   ('for', 'ADP'),
#   ('examination', 'NOUN'),
#   ('only', 'ADV'),
#   ('.', '.'),
#   ("''", '.')],
#  [('A', 'DET'),
#   ('Lorillard', 'NOUN'),
#   ('spokewoman', 'NOUN'),
#   ('said', 'VERB'),
#   (',', '.'),
#   ('``', '.'),
#   ('This', 'DET'),
#   ('is', 'VERB'),
#   ('an', 'DET'),
#   ('old', 'ADJ'),
#   ('story', 'NOUN'),
#   ('.', '.')],
#  [('Timex', 'NOUN'),
#   ('had', 'VERB'),
#   ('requested', 'VERB'),
#   ('duty-free', 'ADJ'),
#   ('treatment', 'NOUN'),
#   ('for', 'ADP'),
#   ('many', 'ADJ'),
#   ('types', 'NOUN'),
#   ('of', 'ADP'),
#   ('watches', 'NOUN'),
#   (',', '.'),
#   ('covered', 'VERB'),
#   ('*', 'X'),
#   ('by', 'ADP'),
#   ('58', 'NUM'),
#   ('different', 'ADJ'),
#   ('U.S.', 'NOUN'),
#   ('tariff', 'NOUN'),
#   ('classifications', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('House', 'NOUN'),
#   ('passed', 'VERB'),
#   ('legislation', 'NOUN'),
#   ('designed', 'VERB'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('make', 'VERB'),
#   ('it', 'PRON'),
#   ('easier', 'ADJ'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('Transportation', 'NOUN'),
#   ('Department', 'NOUN'),
#   ('to', 'PRT'),
#   ('block', 'VERB'),
#   ('airline', 'NOUN'),
#   ('leveraged', 'ADJ'),
#   ('buy-outs', 'NOUN'),
#   ('.', '.')],
#  [('But', 'CONJ'),
#   ('*', 'X'),
#   ('maintaining', 'VERB'),
#   ('U.S.', 'NOUN'),
#   ('influence', 'NOUN'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('difficult', 'ADJ'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('face', 'NOUN'),
#   ('of', 'ADP'),
#   ('Japanese', 'ADJ'),
#   ('dominance', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('region', 'NOUN'),
#   ('.', '.')],
#  [('You', 'PRON'),
#   ('ca', 'VERB'),
#   ("n't", 'ADV'),
#   ('hold', 'VERB'),
#   ('back', 'ADJ'),
#   ('technology', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Some', 'DET'),
#   ('of', 'ADP'),
#   ('his', 'PRON'),
#   ('observations', 'NOUN'),
#   ('about', 'ADP'),
#   ('Japanese', 'ADJ'),
#   ('management', 'NOUN'),
#   ('style', 'NOUN'),
#   ('are', 'VERB'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('mark', 'NOUN'),
#   ('.', '.')],
#  [('That', 'DET'),
#   ('impressed', 'VERB'),
#   ('Robert', 'NOUN'),
#   ('B.', 'NOUN'),
#   ('Pamplin', 'NOUN'),
#   (',', '.'),
#   ('Georgia-Pacific', 'NOUN'),
#   ("'s", 'PRT'),
#   ('chief', 'NOUN'),
#   ('executive', 'ADJ'),
#   ('at', 'ADP'),
#   ('the', 'DET'),
#   ('time', 'NOUN'),
#   (',', '.'),
#   ('whom', 'PRON'),
#   ('Mr.', 'NOUN'),
#   ('Hahn', 'NOUN'),
#   ('had', 'VERB'),
#   ('met', 'VERB'),
#   ('*T*-4', 'X'),
#   ('while', 'ADP'),
#   ('*-1', 'X'),
#   ('fundraising', 'VERB'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('institute', 'NOUN'),
#   ('.', '.')],
#  [('``', '.'),
#   ('These', 'DET'),
#   ('two', 'NUM'),
#   ('exposures', 'NOUN'),
#   ('alone', 'ADV'),
#   ('represent', 'VERB'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('substantial', 'ADJ'),
#   ('portion', 'NOUN'),
#   ('of', 'ADP'),
#   ('CS', 'NOUN'),
#   ('First', 'NOUN'),
#   ('Boston', 'NOUN'),
#   ("'s", 'PRT'),
#   ('equity', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('Moody', 'NOUN'),
#   ("'s", 'PRT'),
#   ('said', 'VERB'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('But', 'CONJ'),
#   ('Asian', 'ADJ'),
#   ('nations', 'NOUN'),
#   ("'", 'PRT'),
#   ('harsh', 'ADJ'),
#   ('memories', 'NOUN'),
#   ('of', 'ADP'),
#   ('their', 'PRON'),
#   ('military', 'ADJ'),
#   ('domination', 'NOUN'),
#   ('by', 'ADP'),
#   ('Japan', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('early', 'ADJ'),
#   ('part', 'NOUN'),
#   ('of', 'ADP'),
#   ('this', 'DET'),
#   ('century', 'NOUN'),
#   ('make', 'VERB'),
#   ('them', 'PRON'),
#   ('fearful', 'ADJ'),
#   ('of', 'ADP'),
#   ('*', 'X'),
#   ('falling', 'VERB'),
#   ('under', 'ADP'),
#   ('Japanese', 'ADJ'),
#   ('economic', 'ADJ'),
#   ('hegemony', 'NOUN'),
#   ('now', 'ADV'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('Communist', 'NOUN'),
#   ('Party', 'NOUN'),
#   ('chief', 'NOUN'),
#   (',', '.'),
#   ('*-1', 'X'),
#   ('in', 'ADP'),
#   ('Moscow', 'NOUN'),
#   ('for', 'ADP'),
#   ('talks', 'NOUN'),
#   ('with', 'ADP'),
#   ('Soviet', 'ADJ'),
#   ('officials', 'NOUN'),
#   (',', '.'),
#   ('also', 'ADV'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('East', 'NOUN'),
#   ('Germany', 'NOUN'),
#   ('would', 'VERB'),
#   ('follow', 'VERB'),
#   ('Gorbachev', 'NOUN'),
#   ("'s", 'PRT'),
#   ('restructuring', 'NOUN'),
#   ('plans', 'NOUN'),
#   ('.', '.')],
#  [('Says', 'VERB'),
#   ('*ICH*-1', 'X'),
#   ('the', 'DET'),
#   ('Big', 'NOUN'),
#   ('Board', 'NOUN'),
#   ("'s", 'PRT'),
#   ('Mr.', 'NOUN'),
#   ('Phelan', 'NOUN'),
#   (',', '.'),
#   ('``', '.'),
#   ('Volatility', 'NOUN'),
#   ('is', 'VERB'),
#   ('greater', 'ADJ'),
#   ('than', 'ADP'),
#   ('program', 'NOUN'),
#   ('trading', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('The', 'DET'),
#   ('last', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('0', 'X'),
#   ('they', 'PRON'),
#   ('needed', 'VERB'),
#   ('*T*-1', 'X'),
#   ('was', 'VERB'),
#   ('another', 'DET'),
#   ('drag-down', 'ADJ'),
#   ('blow', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('But', 'CONJ'),
#   ('we', 'PRON'),
#   ('are', 'VERB'),
#   ('not', 'ADV'),
#   ('going', 'VERB'),
#   ('back', 'ADV'),
#   ('to', 'PRT'),
#   ('1970', 'NUM'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Short', 'ADJ'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('total', 'NOUN'),
#   ('ban', 'NOUN'),
#   (',', '.'),
#   ('some', 'DET'),
#   ('anti-programmers', 'NOUN'),
#   ('have', 'VERB'),
#   ('proposed', 'VERB'),
#   ('several', 'ADJ'),
#   ('middle-ground', 'ADJ'),
#   ('reforms', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('they', 'PRON'),
#   ('say', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('would', 'VERB'),
#   ('take', 'VERB'),
#   ('away', 'PRT'),
#   ('certain', 'ADJ'),
#   ('advantages', 'NOUN'),
#   ('0', 'X'),
#   ('program', 'NOUN'),
#   ('traders', 'NOUN'),
#   ('currently', 'ADV'),
#   ('enjoy', 'VERB'),
#   ('*T*-2', 'X'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('marketplace', 'NOUN'),
#   ('that', 'ADP'),
#   ('other', 'ADJ'),
#   ('investors', 'NOUN'),
#   ('do', 'VERB'),
#   ("n't", 'ADV'),
#   ('*T*-3', 'X'),
#   ('.', '.')],
#  [('60', 'NUM'),
#   ('million', 'NUM'),
#   ('Swiss', 'ADJ'),
#   ('francs', 'NOUN'),
#   ('of', 'ADP'),
#   ('privately', 'ADV'),
#   ('placed', 'VERB'),
#   ('convertible', 'ADJ'),
#   ('notes', 'NOUN'),
#   ('due', 'ADJ'),
#   ('Dec.', 'NOUN'),
#   ('31', 'NUM'),
#   (',', '.'),
#   ('1993', 'NUM'),
#   (',', '.'),
#   ('with', 'ADP'),
#   ('a', 'DET'),
#   ('fixed', 'VERB'),
#   ('0.25', 'NUM'),
#   ('%', 'NOUN'),
#   ('coupon', 'NOUN'),
#   ('at', 'ADP'),
#   ('par', 'NOUN'),
#   ('via', 'ADP'),
#   ('Union', 'NOUN'),
#   ('Bank', 'NOUN'),
#   ('of', 'ADP'),
#   ('Switzerland', 'NOUN'),
#   ('.', '.')],
#  [('*', 'X'), ('Hold', 'VERB'), ('the', 'DET'), ('Putty', 'NOUN'), ('!', '.')],
#  [('But', 'CONJ'),
#   ('any', 'DET'),
#   ('potential', 'ADJ'),
#   ('acquirer', 'NOUN'),
#   ('must', 'VERB'),
#   ('attempt', 'VERB'),
#   ('*-2', 'X'),
#   ('to', 'PRT'),
#   ('reach', 'VERB'),
#   ('some', 'DET'),
#   ('kind', 'NOUN'),
#   ('of', 'ADP'),
#   ('accord', 'NOUN'),
#   ('with', 'ADP'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   ("'s", 'PRT'),
#   ('employees', 'NOUN'),
#   (',', '.'),
#   ('primarily', 'ADV'),
#   ('its', 'PRON'),
#   ('pilots', 'NOUN'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('powerful', 'ADJ'),
#   ('machinists', 'NOUN'),
#   ("'", 'PRT'),
#   ('union', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-1', 'X'),
#   ('has', 'VERB'),
#   ('opposed', 'VERB'),
#   ('a', 'DET'),
#   ('takeover', 'NOUN'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('1976', 'NUM'),
#   (',', '.'),
#   ('for', 'ADP'),
#   ('example', 'NOUN'),
#   (',', '.'),
#   ('dividends', 'NOUN'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('stocks', 'NOUN'),
#   ('in', 'ADP'),
#   ('Standard', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Poor', 'NOUN'),
#   ("'s", 'PRT'),
#   ('500-stock', 'ADJ'),
#   ('index', 'NOUN'),
#   ('soared', 'VERB'),
#   ('10', 'NUM'),
#   ('%', 'NOUN'),
#   (',', '.'),
#   ('following', 'VERB'),
#   ('much', 'ADV'),
#   ('slower', 'ADJ'),
#   ('growth', 'NOUN'),
#   ('the', 'DET'),
#   ('year', 'NOUN'),
#   ('before', 'ADP'),
#   ('.', '.')],
#  [('Wall', 'NOUN'),
#   ('Street', 'NOUN'),
#   ('reacted', 'VERB'),
#   ('favorably', 'ADV'),
#   ('to', 'PRT'),
#   ('Mr.', 'NOUN'),
#   ('McGovern', 'NOUN'),
#   ("'s", 'PRT'),
#   ('departure', 'NOUN'),
#   ('and', 'CONJ'),
#   ('its', 'PRON'),
#   ('implications', 'NOUN'),
#   ('.', '.')],
#  [('Like', 'ADP'),
#   ('other', 'ADJ'),
#   ('forms', 'NOUN'),
#   ('of', 'ADP'),
#   ('arbitrage', 'NOUN'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('merely', 'ADV'),
#   ('seeks', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('take', 'VERB'),
#   ('advantage', 'NOUN'),
#   ('of', 'ADP'),
#   ('momentary', 'ADJ'),
#   ('discrepancies', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('price', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('single', 'ADJ'),
#   ('product', 'NOUN'),
#   ('--', '.'),
#   ('in', 'ADP'),
#   ('this', 'DET'),
#   ('case', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('basket', 'NOUN'),
#   ('of', 'ADP'),
#   ('stocks', 'NOUN'),
#   ('--', '.'),
#   ('in', 'ADP'),
#   ('different', 'ADJ'),
#   ('markets', 'NOUN'),
#   ('--', '.'),
#   ('in', 'ADP'),
#   ('this', 'DET'),
#   ('case', 'NOUN'),
#   ('the', 'DET'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('Stock', 'NOUN'),
#   ('Exchange', 'NOUN'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('Chicago', 'NOUN'),
#   ('futures', 'NOUN'),
#   ('markets', 'NOUN'),
#   ('.', '.')],
#  [('Britain', 'NOUN'),
#   ('has', 'VERB'),
#   ('two', 'NUM'),
#   ('main', 'ADJ'),
#   ('index-arbitrage', 'NOUN'),
#   ('instruments', 'NOUN'),
#   ('.', '.')],
#  [('A', 'DET'),
#   ('painting', 'NOUN'),
#   ('by', 'ADP'),
#   ('August', 'NOUN'),
#   ('Strindberg', 'NOUN'),
#   ('set', 'VERB'),
#   ('a', 'DET'),
#   ('Scandinavian', 'ADJ'),
#   ('price', 'NOUN'),
#   ('record', 'NOUN'),
#   ('when', 'ADV'),
#   ('it', 'PRON'),
#   ('sold', 'VERB'),
#   ('at', 'ADP'),
#   ('auction', 'NOUN'),
#   ('in', 'ADP'),
#   ('Stockholm', 'NOUN'),
#   ('for', 'ADP'),
#   ('$', '.'),
#   ('2.44', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('Says', 'VERB'),
#   ('*ICH*-1', 'X'),
#   ('Kathryn', 'NOUN'),
#   ('McAuley', 'NOUN'),
#   (',', '.'),
#   ('an', 'DET'),
#   ('analyst', 'NOUN'),
#   ('at', 'ADP'),
#   ('First', 'NOUN'),
#   ('Manhattan', 'NOUN'),
#   ('Co.', 'NOUN'),
#   (':', '.'),
#   ('``', '.'),
#   ('This', 'DET'),
#   ('is', 'VERB'),
#   ('the', 'DET'),
#   ('greatest', 'ADJ'),
#   ('acquisition', 'NOUN'),
#   ('challenge', 'NOUN'),
#   ('0', 'X'),
#   ('he', 'PRON'),
#   ('has', 'VERB'),
#   ('faced', 'VERB'),
#   ('*T*-2', 'X'),
#   ('.', '.')],
#  [('Each', 'DET'),
#   ('right', 'NOUN'),
#   ('entitles', 'VERB'),
#   ('the', 'DET'),
#   ('shareholder', 'NOUN'),
#   ('to', 'PRT'),
#   ('buy', 'VERB'),
#   ('$', '.'),
#   ('100', 'NUM'),
#   ('*U*', 'X'),
#   ('face', 'NOUN'),
#   ('amount', 'NOUN'),
#   ('of', 'ADP'),
#   ('13.5', 'NUM'),
#   ('%', 'NOUN'),
#   ('bonds', 'NOUN'),
#   ('due', 'ADJ'),
#   ('1993', 'NUM'),
#   ('and', 'CONJ'),
#   ('warrants', 'VERB'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('buy', 'VERB'),
#   ('23.5', 'NUM'),
#   ('common', 'ADJ'),
#   ('shares', 'NOUN'),
#   ('at', 'ADP'),
#   ('30', 'NUM'),
#   ('cents', 'NOUN'),
#   ('a', 'DET'),
#   ('share', 'NOUN'),
#   ('.', '.')],
#  [('Your', 'PRON'),
#   ('comments', 'NOUN'),
#   ('implied', 'VERB'),
#   ('0', 'X'),
#   ('we', 'PRON'),
#   ('had', 'VERB'),
#   ('discovered', 'VERB'),
#   ('that', 'ADP'),
#   ('the', 'DET'),
#   ('``', '.'),
#   ('principal', 'ADJ'),
#   ('cause', 'NOUN'),
#   ("''", '.'),
#   ('of', 'ADP'),
#   ('homelessness', 'NOUN'),
#   ('is', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('found', 'VERB'),
#   ('*-18', 'X'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('large', 'ADJ'),
#   ('numbers', 'NOUN'),
#   ('of', 'ADP'),
#   ('mentally', 'ADV'),
#   ('ill', 'ADJ'),
#   ('and', 'CONJ'),
#   ('substance-abusing', 'ADJ'),
#   ('people', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('homeless', 'ADJ'),
#   ('population', 'NOUN'),
#   ('.', '.')],
#  [('A', 'DET'),
#   ('series', 'NOUN'),
#   ('of', 'ADP'),
#   ('5,000', 'NUM'),
#   ('or', 'CONJ'),
#   ('so', 'ADV'),
#   ('changes', 'NOUN'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('``', '.'),
#   ('peal', 'NOUN'),
#   ("''", '.'),
#   ('and', 'CONJ'),
#   ('takes', 'VERB'),
#   ('about', 'ADV'),
#   ('three', 'NUM'),
#   ('hours', 'NOUN'),
#   ('.', '.')],
#  [('Texaco', 'NOUN'),
#   ('rose', 'VERB'),
#   ('3\\/4', 'NUM'),
#   ('to', 'PRT'),
#   ('53', 'NUM'),
#   ('3\\/8', 'NUM'),
#   ('as', 'ADP'),
#   ('4.4', 'NUM'),
#   ('million', 'NUM'),
#   ('shares', 'NOUN'),
#   ('changed', 'VERB'),
#   ('hands', 'NOUN'),
#   ('.', '.')],
#  [('So', 'ADP'),
#   ('far', 'ADV'),
#   (',', '.'),
#   ('Mr.', 'NOUN'),
#   ('Hahn', 'NOUN'),
#   ('is', 'VERB'),
#   ('trying', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('entice', 'VERB'),
#   ('Nekoosa', 'NOUN'),
#   ('into', 'ADP'),
#   ('*', 'X'),
#   ('negotiating', 'VERB'),
#   ('a', 'DET'),
#   ('friendly', 'ADJ'),
#   ('surrender', 'NOUN'),
#   ('while', 'ADP'),
#   ('*-1', 'X'),
#   ('talking', 'VERB'),
#   ('tough', 'ADJ'),
#   ('.', '.')],
#  [('Now', 'ADV'),
#   (',', '.'),
#   ('13', 'NUM'),
#   ('years', 'NOUN'),
#   ('later', 'ADV'),
#   (',', '.'),
#   ('Mr.', 'NOUN'),
#   ('Lane', 'NOUN'),
#   ('has', 'VERB'),
#   ('revived', 'VERB'),
#   ('his', 'PRON'),
#   ('Artist', 'NOUN'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('full-length', 'ADJ'),
#   ('movie', 'NOUN'),
#   ('called', 'VERB'),
#   ('*', 'X'),
#   ('``', '.'),
#   ('Sidewalk', 'NOUN'),
#   ('Stories', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('a', 'DET'),
#   ('poignant', 'ADJ'),
#   ('piece', 'NOUN'),
#   ('of', 'ADP'),
#   ('work', 'NOUN'),
#   ('about', 'ADP'),
#   ('a', 'DET'),
#   ('modern-day', 'ADJ'),
#   ('tramp', 'NOUN'),
#   ('.', '.')],
#  [('Still', 'ADV'),
#   (',', '.'),
#   ('some', 'DET'),
#   ('market', 'NOUN'),
#   ('analysts', 'NOUN'),
#   ('say', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('current', 'ADJ'),
#   ('3.3', 'NUM'),
#   ('%', 'NOUN'),
#   ('reading', 'NOUN'),
#   ('is', 'VERB'),
#   ("n't", 'ADV'),
#   ('as', 'ADV'),
#   ('troublesome', 'ADJ'),
#   ('as', 'ADP'),
#   ('it', 'PRON'),
#   ('might', 'VERB'),
#   ('have', 'VERB'),
#   ('been', 'VERB'),
#   ('*?*', 'X'),
#   ('in', 'ADP'),
#   ('years', 'NOUN'),
#   ('past', 'NOUN'),
#   ('.', '.')],
#  [('Travelers', 'NOUN'),
#   ('estimated', 'VERB'),
#   ('that', 'ADP'),
#   ('the', 'DET'),
#   ('California', 'NOUN'),
#   ('earthquake', 'NOUN'),
#   ('last', 'ADJ'),
#   ('month', 'NOUN'),
#   ('will', 'VERB'),
#   ('result', 'VERB'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('fourth-quarter', 'NOUN'),
#   ('pre-tax', 'ADJ'),
#   ('charge', 'NOUN'),
#   ('of', 'ADP'),
#   ('less', 'ADJ'),
#   ('than', 'ADP'),
#   ('$', '.'),
#   ('10', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('Pressures', 'NOUN'),
#   ('began', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('build', 'VERB'),
#   ('.', '.')],
#  [('This', 'DET'),
#   ('will', 'VERB'),
#   ('require', 'VERB'),
#   ('us', 'PRON'),
#   ('to', 'PRT'),
#   ('develop', 'VERB'),
#   ('a', 'DET'),
#   ('much', 'ADV'),
#   ('more', 'ADV'),
#   ('sophisticated', 'ADJ'),
#   ('understanding', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('dynamics', 'NOUN'),
#   ('of', 'ADP'),
#   ('homelessness', 'NOUN'),
#   ('than', 'ADP'),
#   ('we', 'PRON'),
#   ('currently', 'ADV'),
#   ('possess', 'VERB'),
#   ('*?*', 'X'),
#   (',', '.'),
#   ('an', 'DET'),
#   ('understanding', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ('can', 'VERB'),
#   ('be', 'VERB'),
#   ('developed', 'VERB'),
#   ('*-20', 'X'),
#   ('only', 'ADV'),
#   ('through', 'ADP'),
#   ('careful', 'ADJ'),
#   ('study', 'NOUN'),
#   ('and', 'CONJ'),
#   ('research', 'NOUN'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('Mexico', 'NOUN'),
#   ('could', 'VERB'),
#   ('be', 'VERB'),
#   ('one', 'NUM'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('next', 'ADJ'),
#   ('countries', 'NOUN'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('removed', 'VERB'),
#   ('*-2', 'X'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('priority', 'NOUN'),
#   ('list', 'NOUN'),
#   ('because', 'ADP'),
#   ('of', 'ADP'),
#   ('its', 'PRON'),
#   ('efforts', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('craft', 'VERB'),
#   ('a', 'DET'),
#   ('new', 'ADJ'),
#   ('patent', 'NOUN'),
#   ('law', 'NOUN'),
#   ('.', '.')],
#  [('Georgia', 'NOUN'),
#   ('Gulf', 'NOUN'),
#   ('received', 'VERB'),
#   ('a', 'DET'),
#   ('new', 'ADJ'),
#   ('takeover', 'NOUN'),
#   ('bid', 'NOUN'),
#   ('*ICH*-1', 'X'),
#   ('from', 'ADP'),
#   ('investor', 'NOUN'),
#   ('Harold', 'NOUN'),
#   ('Simmons', 'NOUN'),
#   ('and', 'CONJ'),
#   ('NL', 'NOUN'),
#   ('Industries', 'NOUN'),
#   ('of', 'ADP'),
#   ('$', '.'),
#   ('50', 'NUM'),
#   ('*U*', 'X'),
#   ('a', 'DET'),
#   ('share', 'NOUN'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   ('about', 'ADP'),
#   ('$', '.'),
#   ('1.1', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('Three', 'NUM'),
#   ('divisions', 'NOUN'),
#   ('at', 'ADP'),
#   ('American', 'NOUN'),
#   ('Express', 'NOUN'),
#   ('*ICH*-1', 'X'),
#   ('are', 'VERB'),
#   ('working', 'VERB'),
#   ('with', 'ADP'),
#   ('Buick', 'NOUN'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('promotion', 'NOUN'),
#   (':', '.'),
#   ('the', 'DET'),
#   ('establishment', 'NOUN'),
#   ('services', 'NOUN'),
#   ('division', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-57', 'X'),
#   ('is', 'VERB'),
#   ('responsible', 'ADJ'),
#   ('for', 'ADP'),
#   ('all', 'DET'),
#   ('merchants', 'NOUN'),
#   ('and', 'CONJ'),
#   ('companies', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-2', 'X'),
#   ('accept', 'VERB'),
#   ('the', 'DET'),
#   ('card', 'NOUN'),
#   (';', '.'),
#   ('the', 'DET'),
#   ('travel', 'NOUN'),
#   ('division', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('merchandise', 'NOUN'),
#   ('sales', 'NOUN'),
#   ('division', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('sale', 'NOUN'),
#   ('comes', 'VERB'),
#   ('in', 'ADP'),
#   ('place', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('planned', 'VERB'),
#   ('initial', 'ADJ'),
#   ('public', 'ADJ'),
#   ('offering', 'NOUN'),
#   ('of', 'ADP'),
#   ('Lentjes', 'NOUN'),
#   ('stock', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('matter', 'NOUN'),
#   ('``', '.'),
#   ('did', 'VERB'),
#   ("n't", 'ADV'),
#   ('involve', 'VERB'),
#   ('anybody', 'NOUN'),
#   ("'s", 'PRT'),
#   ('securities', 'NOUN'),
#   ('transactions', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('he', 'PRON'),
#   ('added', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('Further', 'ADV'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Herald', 'NOUN'),
#   ('seemed', 'VERB'),
#   ('*-1', 'X'),
#   ('torn', 'VERB'),
#   ('editorially', 'ADV'),
#   ('between', 'ADP'),
#   ('*-3', 'X'),
#   ('keeping', 'VERB'),
#   ('its', 'PRON'),
#   ('old-time', 'ADJ'),
#   ('Hearst', 'NOUN'),
#   ('readership', 'NOUN'),
#   ('--', '.'),
#   ('blue-collar', 'ADJ'),
#   ('and', 'CONJ'),
#   ('sports-oriented', 'ADJ'),
#   ('--', '.'),
#   ('and', 'CONJ'),
#   ('trying', 'VERB'),
#   ('*-2', 'X'),
#   ('to', 'PRT'),
#   ('provide', 'VERB'),
#   ('a', 'DET'),
#   ('sprightly', 'ADJ'),
#   (',', '.'),
#   ('upscale', 'ADJ'),
#   ('alternative', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('sometimes', 'ADV'),
#   ('staid', 'VERB'),
#   ('Times', 'NOUN'),
#   ('.', '.')],
#  [('Carnival', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('it', 'PRON'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('an', 'DET'),
#   ('11', 'NUM'),
#   ('%', 'NOUN'),
#   ('shareholder', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('new', 'ADJ'),
#   ('company', 'NOUN'),
#   ('.', '.')],
#  [('``', '.'),
#   ('This', 'DET'),
#   ('form', 'NOUN'),
#   ('forces', 'VERB'),
#   ('a', 'DET'),
#   ('lawyer', 'NOUN'),
#   ('to', 'PRT'),
#   ('become', 'VERB'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('effect', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('witness', 'NOUN'),
#   ('against', 'ADP'),
#   ('his', 'PRON'),
#   ('client', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('said', 'VERB'),
#   ('*T*-1', 'X'),
#   ('Neal', 'NOUN'),
#   ('R.', 'NOUN'),
#   ('Sonnett', 'NOUN'),
#   (',', '.'),
#   ('president', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('National', 'NOUN'),
#   ('Association', 'NOUN'),
#   ('of', 'ADP'),
#   ('Criminal', 'NOUN'),
#   ('Defense', 'NOUN'),
#   ('Lawyers', 'NOUN'),
#   ('.', '.')],
#  [('Cost-effective', 'ADJ'),
#   ('index', 'NOUN'),
#   ('funds', 'NOUN'),
#   ('just', 'ADV'),
#   ('are', 'VERB'),
#   ("n't", 'ADV'),
#   ('sexy', 'ADJ'),
#   ('enough', 'ADV'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('justify', 'VERB'),
#   ('the', 'DET'),
#   ('high', 'ADJ'),
#   ('fees', 'NOUN'),
#   ('and', 'CONJ'),
#   ('commissions', 'NOUN'),
#   ('that', 'ADP'),
#   ('retail', 'ADJ'),
#   ('customers', 'NOUN'),
#   ('frequently', 'ADV'),
#   ('pay', 'VERB'),
#   ('*T*-1', 'X'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('that', 'ADP'),
#   ('institutional', 'ADJ'),
#   ('customers', 'NOUN'),
#   ('refuse', 'VERB'),
#   ('*-3', 'X'),
#   ('to', 'PRT'),
#   ('pay', 'VERB'),
#   ('*T*-2', 'X'),
#   ('.', '.')],
#  [('We', 'PRON'),
#   ("'re", 'VERB'),
#   ('seeing', 'VERB'),
#   ('it', 'PRON'),
#   ('partly', 'ADV'),
#   ('because', 'ADP'),
#   ('older', 'ADJ'),
#   ('vintages', 'NOUN'),
#   ('are', 'VERB'),
#   ('growing', 'VERB'),
#   ('more', 'ADV'),
#   ('scarce', 'ADJ'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Pamela', 'NOUN'),
#   ('Sebastian', 'NOUN'),
#   ('in', 'ADP'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('contributed', 'VERB'),
#   ('to', 'PRT'),
#   ('this', 'DET'),
#   ('article', 'NOUN'),
#   ('.', '.')],
#  [('While', 'ADP'),
#   ('it', 'PRON'),
#   ('breaks', 'VERB'),
#   ('down', 'PRT'),
#   ('in', 'ADP'),
#   ('prolonged', 'VERB'),
#   ('sunlight', 'NOUN'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('is', 'VERB'),
#   ("n't", 'ADV'),
#   ('recyclable', 'ADJ'),
#   ('.', '.')],
#  [('They', 'PRON'),
#   ('are', 'VERB'),
#   ('keeping', 'VERB'),
#   ('a', 'DET'),
#   ('close', 'ADJ'),
#   ('watch', 'NOUN'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('yield', 'NOUN'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('S&P', 'NOUN'),
#   ('500', 'NUM'),
#   ('.', '.')],
#  [('UAL', 'NOUN'),
#   ('rose', 'VERB'),
#   ('1', 'NUM'),
#   ('1\\/2', 'NUM'),
#   ('to', 'PRT'),
#   ('177', 'NUM'),
#   ('.', '.')],
#  [('There', 'DET'),
#   ('is', 'VERB'),
#   ('also', 'ADV'),
#   ('speculation', 'NOUN'),
#   ('that', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Newhouse', 'NOUN'),
#   ('could', 'VERB'),
#   ('bring', 'VERB'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('powerhouse', 'NOUN'),
#   ('businessman', 'NOUN'),
#   ('or', 'CONJ'),
#   ('another', 'DET'),
#   ('Newhouse', 'NOUN'),
#   ('family', 'NOUN'),
#   ('member', 'NOUN'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('to', 'PRT'),
#   ('run', 'VERB'),
#   ('the', 'DET'),
#   ('business', 'NOUN'),
#   ('side', 'NOUN'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('combination', 'NOUN'),
#   ('with', 'ADP'),
#   ('a', 'DET'),
#   ('publishing', 'NOUN'),
#   ('executive', 'NOUN'),
#   ('like', 'ADP'),
#   ('Robert', 'NOUN'),
#   ('Gottlieb', 'NOUN'),
#   (',', '.'),
#   ('who', 'PRON'),
#   ('*T*-38', 'X'),
#   ('left', 'VERB'),
#   ('Random', 'NOUN'),
#   ('House', 'NOUN'),
#   ("'s", 'PRT'),
#   ('Alfred', 'NOUN'),
#   ('A.', 'NOUN'),
#   ('Knopf', 'NOUN'),
#   ('*-2', 'X'),
#   ('to', 'PRT'),
#   ('run', 'VERB'),
#   ('the', 'DET'),
#   ('New', 'NOUN'),
#   ('Yorker', 'NOUN'),
#   (',', '.'),
#   ('also', 'ADV'),
#   ('owned', 'VERB'),
#   ('*', 'X'),
#   ('by', 'ADP'),
#   ('the', 'DET'),
#   ('Newhouse', 'NOUN'),
#   ('family', 'NOUN'),
#   ('.', '.')],
#  [('Shipments', 'NOUN'),
#   ('have', 'VERB'),
#   ('been', 'VERB'),
#   ('relatively', 'ADV'),
#   ('level', 'ADJ'),
#   ('since', 'ADP'),
#   ('January', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Commerce', 'NOUN'),
#   ('Department', 'NOUN'),
#   ('noted', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('Labor', 'NOUN'),
#   ('Secretary', 'NOUN'),
#   ('Elizabeth', 'NOUN'),
#   ('Dole', 'NOUN'),
#   ('said', 'VERB'),
#   (',', '.'),
#   ('``', '.'),
#   ('The', 'DET'),
#   ('magnitude', 'NOUN'),
#   ('of', 'ADP'),
#   ('these', 'DET'),
#   ('penalties', 'NOUN'),
#   ('and', 'CONJ'),
#   ('citations', 'NOUN'),
#   ('is', 'VERB'),
#   ('matched', 'VERB'),
#   ('*-1', 'X'),
#   ('only', 'ADV'),
#   ('by', 'ADP'),
#   ('the', 'DET'),
#   ('magnitude', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('hazards', 'NOUN'),
#   ('to', 'PRT'),
#   ('workers', 'NOUN'),
#   ('which', 'DET'),
#   ('*T*-14', 'X'),
#   ('resulted', 'VERB'),
#   ('from', 'ADP'),
#   ('corporate', 'ADJ'),
#   ('indifference', 'NOUN'),
#   ('to', 'PRT'),
#   ('worker', 'NOUN'),
#   ('safety', 'NOUN'),
#   ('and', 'CONJ'),
#   ('health', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('severe', 'ADJ'),
#   ('cutbacks', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('maintenance', 'NOUN'),
#   ('and', 'CONJ'),
#   ('repair', 'NOUN'),
#   ('programs', 'NOUN'),
#   ('needed', 'VERB'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('remove', 'VERB'),
#   ('those', 'DET'),
#   ('hazards', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Among', 'ADP'),
#   ('the', 'DET'),
#   ('lot', 'NOUN'),
#   ('of', 'ADP'),
#   ('them', 'PRON'),
#   (',', '.'),
#   ('not', 'ADV'),
#   ('one', 'NUM'),
#   ('is', 'VERB'),
#   ('wrestling', 'VERB'),
#   ('with', 'ADP'),
#   ('good', 'ADJ'),
#   ('and', 'CONJ'),
#   ('evil', 'ADJ'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   ('especially', 'ADV'),
#   ('intelligent', 'ADJ'),
#   ('or', 'CONJ'),
#   ('even', 'ADV'),
#   ('temporarily', 'ADV'),
#   ('insane', 'ADJ'),
#   ('.', '.')],
#  [('To', 'PRT'),
#   ('the', 'DET'),
#   ('extent', 'NOUN'),
#   ('0', 'X'),
#   ('they', 'PRON'),
#   ('can', 'VERB'),
#   ('do', 'VERB'),
#   ('this', 'DET'),
#   ('*T*-3', 'X'),
#   (',', '.'),
#   ('they', 'PRON'),
#   ("'re", 'VERB'),
#   ('quite', 'ADV'),
#   ('content', 'ADJ'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('get', 'VERB'),
#   ('a', 'DET'),
#   ('return', 'NOUN'),
#   ('on', 'ADP'),
#   ('investment', 'NOUN'),
#   ('of', 'ADP'),
#   ('1', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PRT'),
#   ('2', 'NUM'),
#   ('%', 'NOUN'),
#   ('*U*', 'X'),
#   ('.', '.'),
#   ("''", '.')],
#  [('The', 'DET'),
#   ('sale', 'NOUN'),
#   ('represents', 'VERB'),
#   ('10.2', 'NUM'),
#   ('%', 'NOUN'),
#   ('of', 'ADP'),
#   ('Meridian', 'NOUN'),
#   ("'s", 'PRT'),
#   ('shares', 'NOUN'),
#   ('outstanding', 'ADJ'),
#   ('.', '.')],
#  [('Associates', 'NOUN'),
#   ('say', 'VERB'),
#   ('0', 'X'),
#   ('Mr.', 'NOUN'),
#   ('Hahn', 'NOUN'),
#   ('picked', 'VERB'),
#   ('up', 'PRT'),
#   ('that', 'DET'),
#   ('careful', 'ADJ'),
#   ('approach', 'NOUN'),
#   ('to', 'PRT'),
#   ('management', 'NOUN'),
#   ('as', 'ADP'),
#   ('president', 'NOUN'),
#   ('of', 'ADP'),
#   ('Virginia', 'NOUN'),
#   ('Polytechnic', 'NOUN'),
#   ('Institute', 'NOUN'),
#   ('.', '.')],
#  [('Then', 'ADV'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('guests', 'NOUN'),
#   ("'", 'PRT'),
#   ('honor', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('speedway', 'NOUN'),
#   ('hauled', 'VERB'),
#   ('out', 'PRT'),
#   ('four', 'NUM'),
#   ('drivers', 'NOUN'),
#   (',', '.'),
#   ('crews', 'NOUN'),
#   ('and', 'CONJ'),
#   ('even', 'ADV'),
#   ('the', 'DET'),
#   ('official', 'ADJ'),
#   ('Indianapolis', 'NOUN'),
#   ('500', 'NUM'),
#   ('announcer', 'NOUN'),
#   ('for', 'ADP'),
#   ('a', 'DET'),
#   ('10-lap', 'ADJ'),
#   ('exhibition', 'NOUN'),
#   ('race', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('index', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('100', 'NUM'),
#   ('largest', 'ADJ'),
#   ('Nasdaq', 'NOUN'),
#   ('financial', 'ADJ'),
#   ('stocks', 'NOUN'),
#   ('rose', 'VERB'),
#   ('modestly', 'ADV'),
#   ('as', 'ADP'),
#   ('well', 'ADV'),
#   (',', '.'),
#   ('*-1', 'X'),
#   ('gaining', 'VERB'),
#   ('1.28', 'NUM'),
#   ('to', 'PRT'),
#   ('449.04', 'NUM'),
#   ('.', '.')],
#  [('Pan', 'NOUN'),
#   ('Am', 'VERB'),
#   ('has', 'VERB'),
#   ('subpoenaed', 'VERB'),
#   ('several', 'ADJ'),
#   ('government', 'NOUN'),
#   ('agencies', 'NOUN'),
#   (',', '.'),
#   ('including', 'VERB'),
#   ('the', 'DET'),
#   ('CIA', 'NOUN'),
#   ('and', 'CONJ'),
#   ('FBI', 'NOUN'),
#   (',', '.'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('determine', 'VERB'),
#   ('whether', 'ADP'),
#   ('they', 'PRON'),
#   ('were', 'VERB'),
#   ('warned', 'VERB'),
#   ('*-1', 'X'),
#   ('that', 'ADP'),
#   ('a', 'DET'),
#   ('bomb', 'NOUN'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('planted', 'VERB'),
#   ('*-2', 'X'),
#   ('aboard', 'ADP'),
#   ('a', 'DET'),
#   ('jet', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-3', 'X'),
#   ('exploded', 'VERB'),
#   ('over', 'ADP'),
#   ('Scotland', 'NOUN'),
#   ('last', 'ADJ'),
#   ('December', 'NOUN'),
#   (',', '.'),
#   ('*-4', 'X'),
#   ('killing', 'VERB'),
#   ('270', 'NUM'),
#   ('people', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('governor', 'NOUN'),
#   ('could', 'VERB'),
#   ("n't", 'ADV'),
#   ('make', 'VERB'),
#   ('it', 'PRON'),
#   (',', '.'),
#   ('so', 'ADP'),
#   ('the', 'DET'),
#   ('lieutenant', 'NOUN'),
#   ('governor', 'NOUN'),
#   ('welcomed', 'VERB'),
#   ('the', 'DET'),
#   ('special', 'ADJ'),
#   ('guests', 'NOUN'),
#   ('.', '.')],
#  [('Prudential-Bache', 'NOUN'),
#   ('Securities', 'NOUN'),
#   ('boosted', 'VERB'),
#   ('the', 'DET'),
#   ('stock', 'NOUN'),
#   ("'s", 'PRT'),
#   ('short-term', 'ADJ'),
#   ('investment', 'NOUN'),
#   ('rating', 'NOUN'),
#   ('in', 'ADP'),
#   ('response', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('departure', 'NOUN'),
#   (';', '.'),
#   ('analyst', 'NOUN'),
#   ('John', 'NOUN'),
#   ('McMillin', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('he', 'PRON'),
#   ('believes', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   ('will', 'VERB'),
#   ('turn', 'VERB'),
#   ('to', 'PRT'),
#   ('new', 'ADJ'),
#   ('management', 'NOUN'),
#   ('``', '.'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ("'s", 'VERB'),
#   ('more', 'ADV'),
#   ('financially', 'ADV'),
#   ('oriented', 'VERB'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('It', 'PRON'),
#   ('has', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('weigh', 'VERB'),
#   (',', '.'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('other', 'ADJ'),
#   ('hand', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('relatively', 'ADV'),
#   ('high', 'ADJ'),
#   ('price', 'NOUN'),
#   ('of', 'ADP'),
#   ('sugar', 'NOUN'),
#   ('0', 'X'),
#   ('it', 'PRON'),
#   ('can', 'VERB'),
#   ('earn', 'VERB'),
#   ('*T*-3', 'X'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('export', 'NOUN'),
#   ('market', 'NOUN'),
#   ('in', 'ADP'),
#   ('*', 'X'),
#   ('making', 'VERB'),
#   ('decisions', 'NOUN'),
#   ('as', 'ADP'),
#   ('to', 'PRT'),
#   ('whether', 'ADP'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('produce', 'VERB'),
#   ('sugar', 'NOUN'),
#   ('or', 'CONJ'),
#   ('alcohol', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('Mr.', 'NOUN'),
#   ('Oxnard', 'NOUN'),
#   ('said', 'VERB'),
#   ('*T*-2', 'X'),
#   ('.', '.')],
#  [('Japan', 'NOUN'),
#   ("'s", 'PRT'),
#   ('domestic', 'ADJ'),
#   ('sales', 'NOUN'),
#   ('of', 'ADP'),
#   ('cars', 'NOUN'),
#   (',', '.'),
#   ('trucks', 'NOUN'),
#   ('and', 'CONJ'),
#   ('buses', 'NOUN'),
#   ('in', 'ADP'),
#   ('October', 'NOUN'),
#   ('rose', 'VERB'),
#   ('18', 'NUM'),
#   ('%', 'NOUN'),
#   ('from', 'ADP'),
#   ('a', 'DET'),
#   ('year', 'NOUN'),
#   ('earlier', 'ADJ'),
#   ('to', 'PRT'),
#   ('500,004', 'NUM'),
#   ('units', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('record', 'NOUN'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('month', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Japan', 'NOUN'),
#   ('Automobile', 'NOUN'),
#   ('Dealers', 'NOUN'),
#   ("'", 'PRT'),
#   ('Association', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('court', 'NOUN'),
#   ('rejected', 'VERB'),
#   ('strict', 'ADJ'),
#   ('liability', 'NOUN'),
#   ('for', 'ADP'),
#   ('prescription', 'NOUN'),
#   ('drugs', 'NOUN'),
#   (',', '.'),
#   ('*-1', 'X'),
#   ('citing', 'VERB'),
#   ('the', 'DET'),
#   ('huge', 'ADJ'),
#   (',', '.'),
#   ('hidden', 'VERB'),
#   ('social', 'ADJ'),
#   ('costs', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('became', 'VERB'),
#   ('an', 'DET'),
#   ('abortionist', 'NOUN'),
#   ('accidentally', 'ADV'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('continued', 'VERB'),
#   ('because', 'ADP'),
#   ('it', 'PRON'),
#   ('enabled', 'VERB'),
#   ('her', 'PRON'),
#   ('to', 'PRT'),
#   ('buy', 'VERB'),
#   ('jam', 'NOUN'),
#   (',', '.'),
#   ('cocoa', 'NOUN'),
#   ('and', 'CONJ'),
#   ('other', 'ADJ'),
#   ('war-rationed', 'ADJ'),
#   ('goodies', 'NOUN'),
#   ('.', '.')],
#  [('``', '.'),
#   ('We', 'PRON'),
#   ('had', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('do', 'VERB'),
#   ('something', 'NOUN'),
#   ('structurally', 'ADV'),
#   ('and', 'CONJ'),
#   ('radically', 'ADV'),
#   ('different', 'ADJ'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Shearson', 'NOUN'),
#   ('also', 'ADV'),
#   ('has', 'VERB'),
#   ('been', 'VERB'),
#   ('an', 'DET'),
#   ('aggressive', 'ADJ'),
#   ('participant', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('leveraged', 'ADJ'),
#   ('buy-out', 'NOUN'),
#   ('business', 'NOUN'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('his', 'PRON'),
#   ('return', 'NOUN'),
#   ('toast', 'NOUN'),
#   ('to', 'PRT'),
#   ('Mr.', 'NOUN'),
#   ('Nixon', 'NOUN'),
#   (',', '.'),
#   ('Mr.', 'NOUN'),
#   ('Yang', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('relationship', 'NOUN'),
#   ('had', 'VERB'),
#   ('reached', 'VERB'),
#   ('a', 'DET'),
#   ('``', '.'),
#   ('stalemate', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('In', 'ADP'),
#   ('addition', 'NOUN'),
#   (',', '.'),
#   ('operating', 'VERB'),
#   ('results', 'NOUN'),
#   ('were', 'VERB'),
#   ('hit', 'VERB'),
#   ('*-1', 'X'),
#   ('by', 'ADP'),
#   ('an', 'DET'),
#   ('increase', 'NOUN'),
#   ('in', 'ADP'),
#   ('loan', 'NOUN'),
#   ('and', 'CONJ'),
#   ('real', 'ADJ'),
#   ('estate', 'NOUN'),
#   ('loss', 'NOUN'),
#   ('reserves', 'NOUN'),
#   ('.', '.')],
#  [('We', 'PRON'),
#   ('have', 'VERB'),
#   ('made', 'VERB'),
#   ('no', 'DET'),
#   ('such', 'ADJ'),
#   ('statement', 'NOUN'),
#   ('.', '.')],
#  [('Mrs.', 'NOUN'),
#   ('Ward', 'NOUN'),
#   ('says', 'VERB'),
#   ('0', 'X'),
#   ('she', 'PRON'),
#   ('often', 'ADV'),
#   ('defended', 'VERB'),
#   ('her', 'PRON'),
#   ('to', 'PRT'),
#   ('colleagues', 'NOUN'),
#   ('who', 'PRON'),
#   ('*T*-91', 'X'),
#   ('called', 'VERB'),
#   ('her', 'PRON'),
#   ('a', 'DET'),
#   ('grandstander', 'NOUN'),
#   ('.', '.')],
#  [('But', 'CONJ'),
#   ('he', 'PRON'),
#   ('is', 'VERB'),
#   ('best', 'ADJ'),
#   ('known', 'VERB'),
#   ('*-3', 'X'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('auto', 'NOUN'),
#   ('industry', 'NOUN'),
#   ('as', 'ADP'),
#   ('the', 'DET'),
#   ('creator', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('team', 'NOUN'),
#   ('car-development', 'NOUN'),
#   ('approach', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ('produced', 'VERB'),
#   ('the', 'DET'),
#   ('two', 'NUM'),
#   ('midsized', 'VERB'),
#   ('cars', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-2', 'X'),
#   ('were', 'VERB'),
#   ('instrumental', 'ADJ'),
#   ('in', 'ADP'),
#   ('*', 'X'),
#   ('helping', 'VERB'),
#   ('the', 'DET'),
#   ('No.', 'NOUN'),
#   ('2', 'NUM'),
#   ('auto', 'NOUN'),
#   ('maker', 'NOUN'),
#   ('record', 'VERB'),
#   ('profits', 'NOUN'),
#   ('in', 'ADP'),
#   ('recent', 'ADJ'),
#   ('years', 'NOUN'),
#   ('and', 'CONJ'),
#   ('in', 'ADP'),
#   ('*', 'X'),
#   ('enabling', 'VERB'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   ("'s", 'PRT'),
#   ('Ford', 'NOUN'),
#   ('division', 'NOUN'),
#   ('to', 'PRT'),
#   ('eclipse', 'VERB'),
#   ('General', 'NOUN'),
#   ('Motors', 'NOUN'),
#   ('Corp.', 'NOUN'),
#   ("'s", 'PRT'),
#   ('Chevrolet', 'NOUN'),
#   ('division', 'NOUN'),
#   ('as', 'ADP'),
#   ('the', 'DET'),
#   ('top-selling', 'ADJ'),
#   ('nameplate', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('U.S.', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Hahn', 'NOUN'),
#   ('attributes', 'VERB'),
#   ('the', 'DET'),
#   ('gains', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('philosophy', 'NOUN'),
#   ('of', 'ADP'),
#   ('*', 'X'),
#   ('concentrating', 'VERB'),
#   ('on', 'ADP'),
#   ('what', 'PRON'),
#   ('a', 'DET'),
#   ('company', 'NOUN'),
#   ('knows', 'VERB'),
#   ('*T*-1', 'X'),
#   ('best', 'ADJ'),
#   ('.', '.')],
#  [('B.A.T', 'NOUN'),
#   ('Industries', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-2', 'X'),
#   ('is', 'VERB'),
#   ('being', 'VERB'),
#   ('pursued', 'VERB'),
#   ('*-1', 'X'),
#   ('by', 'ADP'),
#   ('Sir', 'NOUN'),
#   ('James', 'NOUN'),
#   ('Goldsmith', 'NOUN'),
#   ("'s", 'PRT'),
#   ('Hoylake', 'NOUN'),
#   ('Investments', 'NOUN'),
#   (',', '.'),
#   ('rose', 'VERB'),
#   ('9', 'NUM'),
#   ('to', 'PRT'),
#   ('753', 'NUM'),
#   ('on', 'ADP'),
#   ('speculation', 'NOUN'),
#   ('that', 'ADP'),
#   ('Hoylake', 'NOUN'),
#   ('will', 'VERB'),
#   ('sweeten', 'VERB'),
#   ('its', 'PRON'),
#   ('bid', 'NOUN'),
#   (',', '.'),
#   ('dealers', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('*T*-3', 'X'),
#   ('.', '.')],
#  [('Standard', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Poor', 'NOUN'),
#   ("'s", 'PRT'),
#   ('500-Stock', 'NOUN'),
#   ('Index', 'NOUN'),
#   ('added', 'VERB'),
#   ('0.84', 'NUM'),
#   ('to', 'PRT'),
#   ('341.20', 'NUM'),
#   (';', '.'),
#   ('the', 'DET'),
#   ('rise', 'NOUN'),
#   ('was', 'VERB'),
#   ('equivalent', 'ADJ'),
#   ('to', 'PRT'),
#   ('a', 'DET'),
#   ('gain', 'NOUN'),
#   ('of', 'ADP'),
#   ('about', 'ADP'),
#   ('six', 'NUM'),
#   ('points', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('industrial', 'ADJ'),
#   ('average', 'NOUN'),
#   ('.', '.')],
#  [('Silver', 'NOUN'),
#   ('is', 'VERB'),
#   ('also', 'ADV'),
#   ('under', 'ADP'),
#   ('pressure', 'NOUN'),
#   ('of', 'ADP'),
#   ('``', '.'),
#   ('extremely', 'ADV'),
#   ('high', 'ADJ'),
#   ("''", '.'),
#   ('inventories', 'NOUN'),
#   ('in', 'ADP'),
#   ('warehouses', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('Commodity', 'NOUN'),
#   ('Exchange', 'NOUN'),
#   (',', '.'),
#   ('he', 'PRON'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('His', 'PRON'),
#   ('wife', 'NOUN'),
#   ('also', 'ADV'),
#   ('works', 'VERB'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('paper', 'NOUN'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('did', 'VERB'),
#   ('his', 'PRON'),
#   ('father', 'NOUN'),
#   ('.', '.')],
#  [('Due', 'ADJ'),
#   ('to', 'PRT'),
#   ('an', 'DET'),
#   ('editing', 'NOUN'),
#   ('error', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('letter', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('editor', 'NOUN'),
#   ('in', 'ADP'),
#   ('yesterday', 'NOUN'),
#   ("'s", 'PRT'),
#   ('edition', 'NOUN'),
#   ('from', 'ADP'),
#   ('Frederick', 'NOUN'),
#   ('H.', 'NOUN'),
#   ('Hallett', 'NOUN'),
#   ('mistakenly', 'ADV'),
#   ('identified', 'VERB'),
#   ('the', 'DET'),
#   ('NRDC', 'NOUN'),
#   ('.', '.')],
#  [('DD', 'NOUN'),
#   ('Acquisition', 'NOUN'),
#   ('Corp.', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('partnership', 'NOUN'),
#   ('of', 'ADP'),
#   ('Unicorp', 'NOUN'),
#   ('Canada', 'NOUN'),
#   ('Corp.', 'NOUN'),
#   ("'s", 'PRT'),
#   ('Kingsbridge', 'NOUN'),
#   ('Capital', 'NOUN'),
#   ('Group', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Cara', 'NOUN'),
#   ('Operations', 'NOUN'),
#   ('Ltd.', 'NOUN'),
#   (',', '.'),
#   ('extended', 'VERB'),
#   ('to', 'PRT'),
#   ('Nov.', 'NOUN'),
#   ('20', 'NUM'),
#   ('its', 'PRON'),
#   ('$', '.'),
#   ('45-a-share', 'ADJ'),
#   ('offer', 'NOUN'),
#   ('for', 'ADP'),
#   ('all', 'DET'),
#   ("Dunkin'", 'NOUN'),
#   ('Donuts', 'NOUN'),
#   ('Inc.', 'NOUN'),
#   ('shares', 'NOUN'),
#   ('outstanding', 'ADJ'),
#   ('.', '.')],
#  [('Reed', 'NOUN'),
#   ('is', 'VERB'),
#   ('paying', 'VERB'),
#   ('an', 'DET'),
#   ('interim', 'ADJ'),
#   ('dividend', 'NOUN'),
#   ('of', 'ADP'),
#   ('4.6', 'NUM'),
#   ('pence', 'NOUN'),
#   (',', '.'),
#   ('up', 'ADV'),
#   ('15', 'NUM'),
#   ('%', 'NOUN'),
#   ('from', 'ADP'),
#   ('4', 'NUM'),
#   ('pence', 'NOUN'),
#   ('a', 'DET'),
#   ('year', 'NOUN'),
#   ('earlier', 'ADJ'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('man', 'NOUN'),
#   (',', '.'),
#   ('whom', 'PRON'),
#   ('it', 'PRON'),
#   ('did', 'VERB'),
#   ('not', 'ADV'),
#   ('name', 'VERB'),
#   ('*T*-63', 'X'),
#   (',', '.'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('found', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('the', 'DET'),
#   ('disease', 'NOUN'),
#   ('after', 'ADP'),
#   ('hospital', 'NOUN'),
#   ('tests', 'NOUN'),
#   ('.', '.')],
#  [('However', 'ADV'),
#   (',', '.'),
#   ('after', 'ADP'),
#   ('two', 'NUM'),
#   ('meetings', 'NOUN'),
#   ('with', 'ADP'),
#   ('the', 'DET'),
#   ('Soviets', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('State', 'NOUN'),
#   ('Department', 'NOUN'),
#   ('spokesman', 'NOUN'),
#   ('said', 'VERB'),
#   ('that', 'ADP'),
#   ('it', 'PRON'),
#   ('*EXP*-1', 'X'),
#   ("'s", 'VERB'),
#   ('``', '.'),
#   ('too', 'ADV'),
#   ('early', 'ADV'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('say', 'VERB'),
#   ("''", '.'),
#   ('whether', 'ADP'),
#   ('that', 'DET'),
#   ('will', 'VERB'),
#   ('happen', 'VERB'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('competitive', 'ADJ'),
#   ('rates', 'NOUN'),
#   ('were', 'VERB'),
#   ('generally', 'ADV'),
#   ('offset', 'VERB'),
#   ('*-1', 'X'),
#   ('by', 'ADP'),
#   ('hefty', 'ADJ'),
#   ('fees', 'NOUN'),
#   ('on', 'ADP'),
#   ('various', 'ADJ'),
#   ('services', 'NOUN'),
#   ('.', '.')],
#  [('By', 'ADP'),
#   ('*-1', 'X'),
#   ('constantly', 'ADV'),
#   ('seeking', 'VERB'),
#   ('*-2', 'X'),
#   ('to', 'PRT'),
#   ('own', 'VERB'),
#   ('the', 'DET'),
#   ('cheapest', 'ADJ'),
#   ('widget', 'NOUN'),
#   (',', '.'),
#   ('index-arbitrage', 'ADJ'),
#   ('traders', 'NOUN'),
#   ('hope', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('add', 'VERB'),
#   ('between', 'ADP'),
#   ('1', 'NUM'),
#   ('%', 'NOUN'),
#   ('and', 'CONJ'),
#   ('3', 'NUM'),
#   ('%', 'NOUN'),
#   ('*U*', 'X'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('annual', 'ADJ'),
#   ('return', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('S&P', 'NOUN'),
#   ('500', 'NUM'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('law', 'NOUN'),
#   ('defines', 'VERB'),
#   ('unfairly', 'ADV'),
#   ('low', 'ADJ'),
#   ('prices', 'NOUN'),
#   ('as', 'ADP'),
#   ('ones', 'NOUN'),
#   ('below', 'ADP'),
#   ('the', 'DET'),
#   ('cost', 'NOUN'),
#   ('of', 'ADP'),
#   ('production', 'NOUN'),
#   ('or', 'CONJ'),
#   ('below', 'ADP'),
#   ('prices', 'NOUN'),
#   ('in', 'ADP'),
#   ('an', 'DET'),
#   ('exporter', 'NOUN'),
#   ("'s", 'PRT'),
#   ('home', 'NOUN'),
#   ('market', 'NOUN'),
#   ('.', '.')],
#  [('``', '.'),
#   ('The', 'DET'),
#   ('public', 'NOUN'),
#   ('is', 'VERB'),
#   ('buying', 'VERB'),
#   ('the', 'DET'),
#   ('market', 'NOUN'),
#   ('when', 'ADV'),
#   ('in', 'ADP'),
#   ('reality', 'NOUN'),
#   ('there', 'DET'),
#   ('is', 'VERB'),
#   ('plenty', 'NOUN'),
#   ('of', 'ADP'),
#   ('grain', 'NOUN'),
#   ('0', 'X'),
#   ('*T*-3', 'X'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('shipped', 'VERB'),
#   ('*-1', 'X'),
#   ('*T*-2', 'X'),
#   (',', '.'),
#   ("''", '.'),
#   ('said', 'VERB'),
#   ('*T*-4', 'X'),
#   ('Bill', 'NOUN'),
#   ('Biedermann', 'NOUN'),
#   (',', '.'),
#   ('Allendale', 'NOUN'),
#   ('Inc.', 'NOUN'),
#   ('research', 'NOUN'),
#   ('director', 'NOUN'),
#   ('.', '.')],
#  [('``', '.'),
#   ('There', 'DET'),
#   ('were', 'VERB'),
#   ('so', 'ADV'),
#   ('many', 'ADJ'),
#   ('economic', 'ADJ'),
#   ('reports', 'NOUN'),
#   ('but', 'CONJ'),
#   ('the', 'DET'),
#   ('market', 'NOUN'),
#   ('did', 'VERB'),
#   ("n't", 'ADV'),
#   ('care', 'VERB'),
#   ('about', 'ADP'),
#   ('any', 'DET'),
#   ('of', 'ADP'),
#   ('them', 'PRON'),
#   (',', '.'),
#   ("''", '.'),
#   ('said', 'VERB'),
#   ('*T*-1', 'X'),
#   ('Kathleen', 'NOUN'),
#   ('Camilli', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('money', 'NOUN'),
#   ('market', 'NOUN'),
#   ('economist', 'NOUN'),
#   ('at', 'ADP'),
#   ('Drexel', 'NOUN'),
#   ('Burnham', 'NOUN'),
#   ('Lambert', 'NOUN'),
#   ('Inc', 'NOUN'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('part', 'NOUN'),
#   (',', '.'),
#   ('prices', 'NOUN'),
#   ('reflect', 'VERB'),
#   ('development', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('market', 'NOUN'),
#   ('structure', 'NOUN'),
#   ('based', 'VERB'),
#   ('*', 'X'),
#   ('on', 'ADP'),
#   ('such', 'ADJ'),
#   ('variables', 'NOUN'),
#   ('as', 'ADP'),
#   ('the', 'DET'),
#   ('number', 'NOUN'),
#   ('of', 'ADP'),
#   ('prints', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('purhasing', 'NOUN'),
#   ('managers', 'NOUN'),
#   ("'", 'PRT'),
#   ('report', 'NOUN'),
#   ('also', 'ADV'),
#   ('added', 'VERB'),
#   ('evidence', 'NOUN'),
#   ('that', 'ADP'),
#   ('inflation', 'NOUN'),
#   ('is', 'VERB'),
#   ('under', 'ADP'),
#   ('control', 'NOUN'),
#   ('.', '.')],
#  [('At', 'ADP'),
#   ('his', 'PRON'),
#   ('new', 'ADJ'),
#   ('job', 'NOUN'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('partner', 'NOUN'),
#   ('in', 'ADP'),
#   ('charge', 'NOUN'),
#   ('of', 'ADP'),
#   ('federal', 'ADJ'),
#   ('litigation', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('Sacramento', 'NOUN'),
#   ('office', 'NOUN'),
#   ('of', 'ADP'),
#   ('Orrick', 'NOUN'),
#   (',', '.'),
#   ('Herrington', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Sutcliffe', 'NOUN'),
#   (',', '.'),
#   ('he', 'PRON'),
#   ('will', 'VERB'),
#   ('make', 'VERB'),
#   ('out', 'PRT'),
#   ('much', 'ADV'),
#   ('better', 'ADV'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('study', 'NOUN'),
#   ('shows', 'VERB'),
#   ('that', 'ADP'),
#   ('nearly', 'ADV'),
#   ('40', 'NUM'),
#   ('%', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('homeless', 'ADJ'),
#   ('population', 'NOUN'),
#   ('is', 'VERB'),
#   ('made', 'VERB'),
#   ('up', 'PRT'),
#   ('*-21', 'X'),
#   ('of', 'ADP'),
#   ('women', 'NOUN'),
#   ('and', 'CONJ'),
#   ('children', 'NOUN'),
#   ('and', 'CONJ'),
#   ('that', 'ADP'),
#   ('only', 'ADV'),
#   ('25', 'NUM'),
#   ('%', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('homeless', 'NOUN'),
#   ('exhibits', 'VERB'),
#   ('some', 'DET'),
#   ('combination', 'NOUN'),
#   ('of', 'ADP'),
#   ('drug', 'NOUN'),
#   (',', '.'),
#   ('alcohol', 'NOUN'),
#   ('and', 'CONJ'),
#   ('mental', 'ADJ'),
#   ('problems', 'NOUN'),
#   ('.', '.')],
#  [('ENERGY', 'NOUN'),
#   (':', '.'),
#   ('Crude', 'ADJ'),
#   ('oil', 'NOUN'),
#   ('futures', 'NOUN'),
#   ('prices', 'NOUN'),
#   ('increased', 'VERB'),
#   ('in', 'ADP'),
#   ('moderate', 'ADJ'),
#   ('trading', 'NOUN'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('much', 'ADJ'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('action', 'NOUN'),
#   ('was', 'VERB'),
#   ('in', 'ADP'),
#   ('heating', 'NOUN'),
#   ('oil', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('new', 'ADJ'),
#   ('securities', 'NOUN'),
#   (',', '.'),
#   ('part', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('federal', 'ADJ'),
#   ('government', 'NOUN'),
#   ("'s", 'PRT'),
#   ('regular', 'ADJ'),
#   ('quarterly', 'ADJ'),
#   ('refunding', 'VERB'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('consist', 'VERB'),
#   ('of', 'ADP'),
#   (':', '.')],
#  [('Mitsubishi', 'NOUN'),
#   ('Pencil', 'NOUN'),
#   ('Co', 'NOUN'),
#   ('.', '.'),
#   ('-LRB-', '.'),
#   ('Japan', 'NOUN'),
#   ('-RRB-', '.'),
#   ('--', '.')],
#  [('A', 'DET'),
#   ('soft', 'ADJ'),
#   ('landing', 'NOUN'),
#   ('is', 'VERB'),
#   ('an', 'DET'),
#   ('economic', 'ADJ'),
#   ('slowdown', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-49', 'X'),
#   ('eases', 'VERB'),
#   ('inflation', 'NOUN'),
#   ('without', 'ADP'),
#   ('*-1', 'X'),
#   ('leading', 'VERB'),
#   ('to', 'PRT'),
#   ('a', 'DET'),
#   ('recession', 'NOUN'),
#   ('.', '.')],
#  [('A', 'DET'),
#   ('year', 'NOUN'),
#   ('earlier', 'ADJ'),
#   (',', '.'),
#   ('net', 'ADJ'),
#   ('income', 'NOUN'),
#   ('was', 'VERB'),
#   ('$', '.'),
#   ('2.1', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   ('six', 'NUM'),
#   ('cents', 'NOUN'),
#   ('a', 'DET'),
#   ('share', 'NOUN'),
#   (',', '.'),
#   ('on', 'ADP'),
#   ('revenue', 'NOUN'),
#   ('of', 'ADP'),
#   ('$', '.'),
#   ('169.9', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('official', 'ADJ'),
#   ('news', 'NOUN'),
#   ('agency', 'NOUN'),
#   ('PAP', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('increases', 'NOUN'),
#   ('were', 'VERB'),
#   ('intended', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('bring', 'VERB'),
#   ('unrealistically', 'ADV'),
#   ('low', 'ADJ'),
#   ('energy', 'NOUN'),
#   ('charges', 'NOUN'),
#   ('into', 'ADP'),
#   ('line', 'NOUN'),
#   ('with', 'ADP'),
#   ('production', 'NOUN'),
#   ('costs', 'NOUN'),
#   ('and', 'CONJ'),
#   ('compensate', 'VERB'),
#   ('for', 'ADP'),
#   ('a', 'DET'),
#   ('rise', 'NOUN'),
#   ('in', 'ADP'),
#   ('coal', 'NOUN'),
#   ('prices', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('Latin', 'NOUN'),
#   ('American', 'NOUN'),
#   ('nation', 'NOUN'),
#   ('has', 'VERB'),
#   ('paid', 'VERB'),
#   ('very', 'ADV'),
#   ('little', 'ADV'),
#   ('on', 'ADP'),
#   ('its', 'PRON'),
#   ('debt', 'NOUN'),
#   ('since', 'ADP'),
#   ('early', 'ADJ'),
#   ('last', 'ADJ'),
#   ('year', 'NOUN'),
#   ('.', '.')],
#  [('After', 'ADP'),
#   ('years', 'NOUN'),
#   ('of', 'ADP'),
#   ('struggling', 'VERB'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Los', 'NOUN'),
#   ('Angeles', 'NOUN'),
#   ('Herald', 'NOUN'),
#   ('Examiner', 'NOUN'),
#   ('will', 'VERB'),
#   ('publish', 'VERB'),
#   ('its', 'PRON'),
#   ('last', 'ADJ'),
#   ('edition', 'NOUN'),
#   ('today', 'NOUN'),
# ...
#   ('interest', 'NOUN'),
#   (',', '.'),
#   ('prompted', 'VERB'),
#   ('the', 'DET'),
#   ('improvements', 'NOUN'),
#   ('made', 'VERB'),
#   ('*', 'X'),
#   ('by', 'ADP'),
#   ('South', 'NOUN'),
#   ('Korea', 'NOUN'),
#   (',', '.'),
#   ('Taiwan', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Saudi', 'NOUN'),
#   ('Arabia', 'NOUN'),
#   ('.', '.')],
#  [('Freeport-McMoRan', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('New', 'NOUN'),
#   ('Orleans-based', 'ADJ'),
#   ('diversified', 'ADJ'),
#   ('energy', 'NOUN'),
#   ('conglomerate', 'NOUN'),
#   (',', '.'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('partnership', 'NOUN'),
#   ('will', 'VERB'),
#   ('exchange', 'VERB'),
#   ('its', 'PRON'),
#   ('assets', 'NOUN'),
#   ('for', 'ADP'),
#   ('common', 'ADJ'),
#   ('shares', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('yet-to-be-formed', 'ADJ'),
#   ('entity', 'NOUN'),
#   ('.', '.')],
#  [('Carnival', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-1', 'X'),
#   ('has', 'VERB'),
#   ('three', 'NUM'),
#   ('ships', 'NOUN'),
#   ('on', 'ADP'),
#   ('order', 'NOUN'),
#   ('from', 'ADP'),
#   ('Waertsilae', 'NOUN'),
#   ('Marine', 'NOUN'),
#   (',', '.'),
#   ('presented', 'VERB'),
#   ('claims', 'NOUN'),
#   ('for', 'ADP'),
#   ('$', '.'),
#   ('1.5', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   ('damages', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('bankruptcy', 'NOUN'),
#   ('court', 'NOUN'),
#   ('this', 'DET'),
#   ('week', 'NOUN'),
#   ('.', '.')],
#  [('So', 'ADV'),
#   ('if', 'ADP'),
#   ('index', 'NOUN'),
#   ('arbitrage', 'NOUN'),
#   ('is', 'VERB'),
#   ('simply', 'ADV'),
#   ('*', 'X'),
#   ('taking', 'VERB'),
#   ('advantage', 'NOUN'),
#   ('of', 'ADP'),
#   ('thin', 'ADJ'),
#   ('inefficiencies', 'NOUN'),
#   ('between', 'ADP'),
#   ('two', 'NUM'),
#   ('markets', 'NOUN'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('same', 'ADJ'),
#   ('widget', 'NOUN'),
#   (',', '.'),
#   ('how', 'ADV'),
#   ('did', 'VERB'),
#   ('``', '.'),
#   ('program', 'NOUN'),
#   ('trading', 'NOUN'),
#   ("''", '.'),
#   ('evolve', 'VERB'),
#   ('into', 'ADP'),
#   ('the', 'DET'),
#   ('evil', 'ADJ'),
#   ('creature', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-2', 'X'),
#   ('is', 'VERB'),
#   ('evoking', 'VERB'),
#   ('the', 'DET'),
#   ('curses', 'NOUN'),
#   ('of', 'ADP'),
#   ('so', 'ADV'),
#   ('many', 'ADJ'),
#   ('observers', 'NOUN'),
#   ('*T*-1', 'X'),
#   ('?', '.')],
#  [('Moody', 'NOUN'),
#   ("'s", 'PRT'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('average', 'ADJ'),
#   ('net', 'NOUN'),
#   ('asset', 'NOUN'),
#   ('value', 'NOUN'),
#   ('of', 'ADP'),
#   ('24', 'NUM'),
#   ('junk-bond', 'NOUN'),
#   ('mutual', 'ADJ'),
#   ('funds', 'NOUN'),
#   ('fell', 'VERB'),
#   ('by', 'ADP'),
#   ('4.2', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('October', 'NOUN'),
#   ('.', '.')],
#  [('Gasoline', 'NOUN'),
#   ('futures', 'NOUN'),
#   ('continued', 'VERB'),
#   ('a', 'DET'),
#   ('sell-off', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ('began', 'VERB'),
#   ('Monday', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('new', 'ADJ'),
#   ('company', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('it', 'PRON'),
#   ('believes', 'VERB'),
#   ('0', 'X'),
#   ('there', 'DET'),
#   ('are', 'VERB'),
#   ('fewer', 'ADJ'),
#   ('than', 'ADP'),
#   ('100', 'NUM'),
#   ('potential', 'ADJ'),
#   ('customers', 'NOUN'),
#   ('for', 'ADP'),
#   ('supercomputers', 'NOUN'),
#   ('priced', 'VERB'),
#   ('*', 'X'),
#   ('between', 'ADP'),
#   ('$', '.'),
#   ('15', 'NUM'),
#   ('million', 'NUM'),
#   ('and', 'CONJ'),
#   ('$', '.'),
#   ('30', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('--', '.'),
#   ('presumably', 'ADV'),
#   ('the', 'DET'),
#   ('Cray-3', 'NOUN'),
#   ('price', 'NOUN'),
#   ('range', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('was', 'VERB'),
#   ('untrained', 'ADJ'),
#   ('and', 'CONJ'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('one', 'NUM'),
#   ('botched', 'ADJ'),
#   ('job', 'NOUN'),
#   ('killed', 'VERB'),
#   ('a', 'DET'),
#   ('client', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('says', 'VERB'),
#   ('0', 'X'),
#   ('she', 'PRON'),
#   ('offered', 'VERB'),
#   ('Mrs.', 'NOUN'),
#   ('Yeargin', 'NOUN'),
#   ('a', 'DET'),
#   ('quiet', 'ADJ'),
#   ('resignation', 'NOUN'),
#   ('and', 'CONJ'),
#   ('thought', 'VERB'),
#   ('0', 'X'),
#   ('she', 'PRON'),
#   ('could', 'VERB'),
#   ('help', 'VERB'),
#   ('*-1', 'X'),
#   ('save', 'VERB'),
#   ('her', 'PRON'),
#   ('teaching', 'NOUN'),
#   ('certificate', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('beds', 'NOUN'),
#   ('at', 'ADP'),
#   ('the', 'DET'),
#   ('Bowery', 'NOUN'),
#   ('Mission', 'NOUN'),
#   ('seem', 'VERB'),
#   ('far', 'ADJ'),
#   ('drearier', 'ADV'),
#   ('when', 'ADV'),
#   ('he', 'PRON'),
#   ('has', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('tuck', 'VERB'),
#   ('a', 'DET'),
#   ('little', 'ADJ'),
#   ('girl', 'NOUN'),
#   ('into', 'ADP'),
#   ('one', 'NUM'),
#   ('of', 'ADP'),
#   ('them', 'PRON'),
#   ('at', 'ADP'),
#   ('night', 'NOUN'),
#   ('*T*-2', 'X'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ("'s", 'VERB'),
#   ('hardly', 'ADV'),
#   ('a', 'DET'),
#   ('question', 'NOUN'),
#   ('of', 'ADP'),
#   ('quality', 'NOUN'),
#   ('--', '.'),
#   ('the', 'NUM'),
#   ('1982', 'NUM'),
#   ('Salon', 'NOUN'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('beautiful', 'ADJ'),
#   ('wine', 'NOUN'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Pratt', 'NOUN'),
#   ('noted', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   (',', '.'),
#   ('people', 'NOUN'),
#   ('have', 'VERB'),
#   ('their', 'PRON'),
#   ('own', 'ADJ'),
#   ('ideas', 'NOUN'),
#   ('about', 'ADP'),
#   ('value', 'NOUN'),
#   ('.', '.')],
#  [('FAMILY', 'NOUN'),
#   ('PETS', 'NOUN'),
#   ('are', 'VERB'),
#   ('improving', 'VERB'),
#   ('recovery', 'NOUN'),
#   ('rates', 'NOUN'),
#   ('of', 'ADP'),
#   ('patients', 'NOUN'),
#   ('at', 'ADP'),
#   ('Columbia', 'NOUN'),
#   ('Hospital', 'NOUN'),
#   (',', '.'),
#   ('Milwaukee', 'NOUN'),
#   ('.', '.')],
#  [('Weatherly', 'NOUN'),
#   ('Securities', 'NOUN'),
#   ('Corp.', 'NOUN'),
#   (',', '.'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('three', 'NUM'),
#   ('of', 'ADP'),
#   ('its', 'PRON'),
#   ('principals', 'NOUN'),
#   ('--', '.'),
#   ('Dell', 'NOUN'),
#   ('Eugene', 'NOUN'),
#   ('Keehn', 'NOUN'),
#   ('and', 'CONJ'),
#   ('William', 'NOUN'),
#   ('Northy', 'NOUN'),
#   ('Prater', 'NOUN'),
#   ('Jr.', 'NOUN'),
#   (',', '.'),
#   ('both', 'DET'),
#   ('of', 'ADP'),
#   ('Mercer', 'NOUN'),
#   ('Island', 'NOUN'),
#   (',', '.'),
#   ('Wash.', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('Thomas', 'NOUN'),
#   ('Albert', 'NOUN'),
#   ('McFall', 'NOUN'),
#   (',', '.'),
#   ('of', 'ADP'),
#   ('Red', 'NOUN'),
#   ('Bank', 'NOUN'),
#   (',', '.'),
#   ('N.J', 'NOUN'),
#   ('.', '.'),
#   ('--', '.'),
#   ('consented', 'VERB'),
#   ('to', 'PRT'),
#   ('a', 'DET'),
#   ('fine', 'NOUN'),
#   ('of', 'ADP'),
#   ('$', '.'),
#   ('20,000', 'NUM'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('finding', 'NOUN'),
#   ('marks', 'VERB'),
#   ('a', 'DET'),
#   ('significant', 'ADJ'),
#   ('step', 'NOUN'),
#   ('in', 'ADP'),
#   ('research', 'NOUN'),
#   ('on', 'ADP'),
#   ('``', '.'),
#   ('bulk', 'NOUN'),
#   ("''", '.'),
#   ('superconductors', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-2', 'X'),
#   ('are', 'VERB'),
#   ('aimed', 'VERB'),
#   ('*-1', 'X'),
#   ('at', 'ADP'),
#   ('use', 'NOUN'),
#   ('in', 'ADP'),
#   ('wires', 'NOUN'),
#   ('for', 'ADP'),
#   ('motors', 'NOUN'),
#   (',', '.'),
#   ('magnets', 'NOUN'),
#   (',', '.'),
#   ('generators', 'NOUN'),
#   ('and', 'CONJ'),
#   ('other', 'ADJ'),
#   ('applications', 'NOUN'),
#   ('.', '.')],
#  [('For', 'ADP'),
#   ('10', 'NUM'),
#   ('years', 'NOUN'),
#   (',', '.'),
#   ('Genie', 'NOUN'),
#   ('Driskill', 'NOUN'),
#   ('went', 'VERB'),
#   ('to', 'PRT'),
#   ('her', 'PRON'),
#   ('neighborhood', 'NOUN'),
#   ('bank', 'NOUN'),
#   ('because', 'ADP'),
#   ('it', 'PRON'),
#   ('was', 'VERB'),
#   ('convenient', 'ADJ'),
#   ('.', '.')],
#  [('Relations', 'NOUN'),
#   ('between', 'ADP'),
#   ('China', 'NOUN'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('U.S.', 'NOUN'),
#   ('have', 'VERB'),
#   ('been', 'VERB'),
#   ('tense', 'ADJ'),
#   ('since', 'ADP'),
#   ('June', 'NOUN'),
#   ('7', 'NUM'),
#   (',', '.'),
#   ('when', 'ADV'),
#   ('Chinese', 'ADJ'),
#   ('dissident', 'NOUN'),
#   ('Fang', 'NOUN'),
#   ('Lizhi', 'NOUN'),
#   ('and', 'CONJ'),
#   ('his', 'PRON'),
#   ('wife', 'NOUN'),
#   (',', '.'),
#   ('Li', 'NOUN'),
#   ('Shuxian', 'NOUN'),
#   (',', '.'),
#   ('took', 'VERB'),
#   ('refuge', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('U.S.', 'NOUN'),
#   ('Embassy', 'NOUN'),
#   ('in', 'ADP'),
#   ('Beijing', 'NOUN'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('FEDERAL', 'NOUN'),
#   ('HOME', 'NOUN'),
#   ('LOAN', 'NOUN'),
#   ('MORTGAGE', 'NOUN'),
#   ('CORP', 'NOUN'),
#   ('.', '.'),
#   ('-LRB-', '.'),
#   ('Freddie', 'NOUN'),
#   ('Mac', 'NOUN'),
#   ('-RRB-', '.'),
#   (':', '.'),
#   ('Posted', 'VERB'),
#   ('yields', 'NOUN'),
#   ('on', 'ADP'),
#   ('30-year', 'ADJ'),
#   ('mortgage', 'NOUN'),
#   ('commitments', 'NOUN'),
#   ('for', 'ADP'),
#   ('delivery', 'NOUN'),
#   ('within', 'ADP'),
#   ('30', 'NUM'),
#   ('days', 'NOUN'),
#   ('.', '.')],
#  [('Net', 'ADJ'),
#   ('income', 'NOUN'),
#   ('surged', 'VERB'),
#   ('31', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PRT'),
#   ('7.63', 'NUM'),
#   ('billion', 'NUM'),
#   ('yen', 'NOUN'),
#   ('from', 'ADP'),
#   ('5.82', 'NUM'),
#   ('billion', 'NUM'),
#   ('yen', 'NOUN'),
#   ('.', '.')],
#  [('Lancaster', 'NOUN'),
#   ('Colony', 'NOUN'),
#   ('Corp.', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('it', 'PRON'),
#   ('acquired', 'VERB'),
#   ('Reames', 'NOUN'),
#   ('Foods', 'NOUN'),
#   ('Inc.', 'NOUN'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('cash', 'NOUN'),
#   ('transaction', 'NOUN'),
#   ('.', '.')],
#  [('Yet', 'ADV'),
#   ('this', 'DET'),
#   ('woman', 'NOUN'),
#   (',', '.'),
#   ('Marie-Louise', 'NOUN'),
#   ('Giraud', 'NOUN'),
#   (',', '.'),
#   ('carries', 'VERB'),
#   ('historical', 'ADJ'),
#   ('significance', 'NOUN'),
#   (',', '.'),
#   ('both', 'DET'),
#   ('as', 'ADP'),
#   ('one', 'NUM'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('last', 'ADJ'),
#   ('women', 'NOUN'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('executed', 'VERB'),
#   ('*-2', 'X'),
#   ('in', 'ADP'),
#   ('France', 'NOUN'),
#   ('and', 'CONJ'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('symbol', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('Vichy', 'NOUN'),
#   ('government', 'NOUN'),
#   ("'s", 'PRT'),
#   ('hypocrisy', 'NOUN'),
#   ('.', '.')],
#  [('A', 'DET'),
#   ('lack', 'NOUN'),
#   ('of', 'ADP'),
#   ('enthusiasm', 'NOUN'),
#   ('with', 'ADP'),
#   ('the', 'DET'),
#   ('latest', 'ADJ'),
#   ('economic', 'ADJ'),
#   ('data', 'NOUN'),
#   ('hampered', 'VERB'),
#   ('the', 'DET'),
#   ('stock', 'NOUN'),
#   ('market', 'NOUN'),
#   ("'s", 'PRT'),
#   ('bid', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('extend', 'VERB'),
#   ('Tuesday', 'NOUN'),
#   ("'s", 'PRT'),
#   ('sharp', 'ADJ'),
#   ('gains', 'NOUN'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('prices', 'NOUN'),
#   ('closed', 'VERB'),
#   ('slightly', 'ADV'),
#   ('higher', 'ADJ'),
#   ('in', 'ADP'),
#   ('sluggish', 'ADJ'),
#   ('trading', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('heated', 'ADJ'),
#   ('talk', 'NOUN'),
#   ('stirred', 'VERB'),
#   ('*-1', 'X'),
#   ('up', 'PRT'),
#   ('by', 'ADP'),
#   ('recent', 'ADJ'),
#   ('Japanese', 'ADJ'),
#   ('investments', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('U.S.', 'NOUN'),
#   ('is', 'VERB'),
#   ('focusing', 'VERB'),
#   ('attention', 'NOUN'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('differences', 'NOUN'),
#   ('in', 'ADP'),
#   ('investment', 'NOUN'),
#   ('climate', 'NOUN'),
#   (',', '.'),
#   ('even', 'ADV'),
#   ('though', 'ADP'),
#   ('it', 'PRON'),
#   ("'s", 'VERB'),
#   ('only', 'ADV'),
#   ('one', 'NUM'),
#   ('of', 'ADP'),
#   ('many', 'ADJ'),
#   ('subjects', 'NOUN'),
#   ('0', 'X'),
#   ('*T*-2', 'X'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('covered', 'VERB'),
#   ('*-116', 'X'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('bilateral', 'ADJ'),
#   ('talks', 'NOUN'),
#   (',', '.'),
#   ('known', 'VERB'),
#   ('*', 'X'),
#   ('as', 'ADP'),
#   ('the', 'DET'),
#   ('Structural', 'NOUN'),
#   ('Impediments', 'NOUN'),
#   ('Initiative', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Cray', 'NOUN'),
#   (',', '.'),
#   ('who', 'PRON'),
#   ('*T*-1', 'X'),
#   ('could', 'VERB'),
#   ("n't", 'ADV'),
#   ('be', 'VERB'),
#   ('reached', 'VERB'),
#   ('*-24', 'X'),
#   ('for', 'ADP'),
#   ('comment', 'NOUN'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('work', 'VERB'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('new', 'ADJ'),
#   ('Colorado', 'NOUN'),
#   ('Springs', 'NOUN'),
#   (',', '.'),
#   ('Colo.', 'NOUN'),
#   (',', '.'),
#   ('company', 'NOUN'),
#   ('as', 'ADP'),
#   ('an', 'DET'),
#   ('independent', 'ADJ'),
#   ('contractor', 'NOUN'),
#   ('--', '.'),
#   ('the', 'DET'),
#   ('arrangement', 'NOUN'),
#   ('0', 'X'),
#   ('he', 'PRON'),
#   ('had', 'VERB'),
#   ('*T*-2', 'X'),
#   ('with', 'ADP'),
#   ('Cray', 'NOUN'),
#   ('Research', 'NOUN'),
#   ('.', '.')],
#  [('Dealers', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('dollar', 'NOUN'),
#   ('merely', 'ADV'),
#   ('drifted', 'VERB'),
#   ('lower', 'ADV'),
#   ('following', 'VERB'),
#   ('the', 'DET'),
#   ('release', 'NOUN'),
#   ('Wednesday', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('U.S.', 'NOUN'),
#   ('purchasing', 'NOUN'),
#   ('managers', 'NOUN'),
#   ("'", 'PRT'),
#   ('report', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('attacks', 'NOUN'),
#   ('began', 'VERB'),
#   ('when', 'ADV'),
#   ('Democratic', 'ADJ'),
#   ('Rep.', 'NOUN'),
#   ('James', 'NOUN'),
#   ('Florio', 'NOUN'),
#   ('aired', 'VERB'),
#   ('an', 'DET'),
#   ('ad', 'NOUN'),
#   ('featuring', 'VERB'),
#   ('a', 'DET'),
#   ('drawing', 'NOUN'),
#   ('of', 'ADP'),
#   ('Pinocchio', 'NOUN'),
#   ('and', 'CONJ'),
#   ('a', 'DET'),
#   ('photograph', 'NOUN'),
#   ('of', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Florio', 'NOUN'),
#   ("'s", 'PRT'),
#   ('rival', 'NOUN'),
#   (',', '.'),
#   ('Republican', 'ADJ'),
#   ('Rep.', 'NOUN'),
#   ('Jim', 'NOUN'),
#   ('Courter', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('move', 'NOUN'),
#   ('would', 'VERB'),
#   ('result', 'VERB'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('after-tax', 'ADJ'),
#   ('charge', 'NOUN'),
#   ('of', 'ADP'),
#   ('less', 'ADJ'),
#   ('than', 'ADP'),
#   ('$', '.'),
#   ('4', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('0', 'X'),
#   ('*T*-2', 'X'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('spread', 'VERB'),
#   ('*-1', 'X'),
#   ('over', 'ADP'),
#   ('the', 'DET'),
#   ('next', 'ADJ'),
#   ('three', 'NUM'),
#   ('quarters', 'NOUN'),
#   ('.', '.')],
#  [('For', 'ADP'),
#   ('the', 'DET'),
#   ('year', 'NOUN'),
#   ('ended', 'VERB'),
#   ('Sept.', 'NOUN'),
#   ('30', 'NUM'),
#   (',', '.'),
#   ('Ralston', 'NOUN'),
#   ('earned', 'VERB'),
#   ('$', '.'),
#   ('422.5', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   ('$', '.'),
#   ('6.44', 'NUM'),
#   ('*U*', 'X'),
#   ('a', 'DET'),
#   ('share', 'NOUN'),
#   (',', '.'),
#   ('up', 'ADV'),
#   ('8.9', 'NUM'),
#   ('%', 'NOUN'),
#   ('from', 'ADP'),
#   ('$', '.'),
#   ('387.8', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   ('$', '.'),
#   ('5.63', 'NUM'),
#   ('*U*', 'X'),
#   ('a', 'DET'),
#   ('share', 'NOUN'),
#   ('.', '.')],
#  [('After', 'ADP'),
#   ('numerous', 'ADJ'),
#   ('occurrences', 'NOUN'),
#   ('of', 'ADP'),
#   ('questionable', 'ADJ'),
#   ('teacher', 'NOUN'),
#   ('help', 'NOUN'),
#   ('to', 'PRT'),
#   ('students', 'NOUN'),
#   (',', '.'),
#   ('Texas', 'NOUN'),
#   ('is', 'VERB'),
#   ('revising', 'VERB'),
#   ('its', 'PRON'),
#   ('security', 'NOUN'),
#   ('practices', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('additional', 'ADJ'),
#   ('technology', 'NOUN'),
#   (',', '.'),
#   ('personnel', 'NOUN'),
#   ('training', 'NOUN'),
#   ('and', 'CONJ'),
#   ('promotional', 'ADJ'),
#   ('effort', 'NOUN'),
#   ('can', 'VERB'),
#   ('be', 'VERB'),
#   ('expensive', 'ADJ'),
#   ('.', '.')],
#  [('Output', 'NOUN'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('gradually', 'ADV'),
#   ('increased', 'VERB'),
#   ('*-1', 'X'),
#   ('until', 'ADP'),
#   ('it', 'PRON'),
#   ('reaches', 'VERB'),
#   ('about', 'ADP'),
#   ('11,000', 'NUM'),
#   ('barrels', 'NOUN'),
#   ('a', 'DET'),
#   ('day', 'NOUN'),
#   ('.', '.')],
#  [('Neither', 'DET'),
#   ('Equus', 'NOUN'),
#   ('nor', 'CONJ'),
#   ('Tony', 'NOUN'),
#   ('Lama', 'NOUN'),
#   ('gave', 'VERB'),
#   ('a', 'DET'),
#   ('reason', 'NOUN'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('changed', 'VERB'),
#   ('offer', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Tony', 'NOUN'),
#   ('Lama', 'NOUN'),
#   ('could', 'VERB'),
#   ("n't", 'ADV'),
#   ('be', 'VERB'),
#   ('reached', 'VERB'),
#   ('*-1', 'X'),
#   ('for', 'ADP'),
#   ('comment', 'NOUN'),
#   ('.', '.')],
#  [('--', '.'), ('Pat', 'NOUN'), ("D'Amico", 'NOUN'), ('.', '.')],
#  ...]

# %%
train_words=[tup for data in train_set for tup in data]
test_words=[tup for data in test_set for tup in data]

# %%
vocab={word for word,tag in train_words}
print("Vocabulary of the Corpus",len(vocab))
tags={tag for word,tag in train_words}
print("Number of Tags in the Corpus ",len(tags))
# Out:
# Vocabulary of the Corpus 11052
# Number of Tags in the Corpus  12

# %%
print("Number of Sentences in Training Data ",len(train_set))
print("Number of Sentences in Testing Data ",len(test_set))
# Out:
# Number of Sentences in Training Data  3131
# Number of Sentences in Testing Data  783

# %%
def emission_prob(word, tag, train_bag = train_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)#total number of times the passed tag occurred in train_bag
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
#now calculate the total number of times the passed word occurred as the passed tag.
    count_w_given_tag = len(w_given_tag_list)

    
    return (count_w_given_tag, count_tag)

# %%
def transition_prob(t2, t1, train_bag = train_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
tags_matrix = np.zeros((len(tags), len(tags)), dtype='float32')
for i, t1 in enumerate(list(tags)):
    for j, t2 in enumerate(list(tags)): 
        tags_matrix[i, j] = transition_prob(t2, t1)[0]/transition_prob(t2, t1)[1]

print(tags_matrix)
# Out:
# [[6.83371304e-03 5.01138950e-03 6.83371304e-03 3.69020514e-02
#   4.19134386e-02 9.56719834e-03 4.84738052e-01 1.41230067e-02
#   7.06150308e-02 8.83826911e-02 2.12756261e-01 2.23234631e-02]
#  [6.03732169e-02 5.48847427e-04 4.06147093e-02 5.70801310e-02
#   3.51262353e-02 1.23490669e-01 1.50384188e-01 4.39077942e-03
#   1.13611415e-01 9.33040585e-03 3.49066973e-01 5.59824370e-02]
#  [1.42806140e-03 1.42806144e-02 1.84219927e-01 3.57015361e-03
#   1.19243130e-01 3.57015361e-03 2.07068902e-02 2.60621198e-02
#   3.53445187e-02 2.02427700e-01 3.51660132e-01 3.74866128e-02]
#  [1.20248254e-02 6.98215654e-03 2.98681147e-02 8.14584941e-02
#   1.39255241e-01 7.13731572e-02 3.39022487e-01 1.47401085e-02
#   1.30721495e-01 2.28859577e-02 3.21955010e-02 1.19472459e-01]
#  [6.87694475e-02 6.00793920e-02 7.82104954e-02 5.25694676e-02
#   9.23720598e-02 1.72191828e-01 8.96899477e-02 2.78940029e-03
#   4.61323895e-02 2.56410260e-02 2.18538776e-01 9.29084867e-02]
#  [3.30602261e-03 4.31220367e-04 2.28546783e-02 1.20741697e-02
#   1.73925534e-02 6.03708485e-03 4.02472317e-02 2.87480245e-04
#   2.06410810e-01 4.51343954e-02 6.35906279e-01 9.91806854e-03]
#  [3.55432779e-02 5.43278083e-03 2.28360966e-02 8.38858187e-02
#   3.48066315e-02 1.33609578e-01 1.67955801e-01 3.06629837e-02
#   6.63904250e-02 2.15930015e-01 1.10589318e-01 9.23572779e-02]
#  [1.76125243e-02 2.34833662e-03 5.67514673e-02 9.39334650e-03
#   4.50097844e-02 1.01369865e-01 4.01174158e-01 1.17416831e-03
#   8.29745606e-02 1.21330721e-02 2.50489235e-01 1.95694715e-02]
#  [1.94174761e-04 1.68932043e-02 2.17475723e-02 5.24271838e-03
#   6.60194159e-02 5.24271838e-03 1.14563107e-02 1.14563107e-02
#   6.33009672e-02 2.09708735e-02 6.96893215e-01 8.05825219e-02]
#  [5.41995019e-02 1.03786280e-02 3.07514891e-03 2.57543717e-02
#   1.60868734e-01 5.68902567e-02 2.06419379e-01 1.85085520e-01
#   1.76821072e-02 7.57255405e-02 6.16951771e-02 1.42225638e-01]
#  [4.65906132e-03 4.24540639e-02 9.14395228e-03 1.68945398e-02
#   2.40094051e-01 1.31063312e-02 1.49133503e-01 4.39345129e-02
#   1.25838192e-02 2.88252197e-02 2.62344331e-01 1.76826611e-01]
#  [6.96026310e-02 1.01240189e-03 6.32751212e-02 1.45532778e-02
#   3.87243740e-02 3.20931405e-01 8.47886596e-03 1.26550242e-03
#   1.07061505e-01 3.45482156e-02 3.23588967e-01 1.69577319e-02]]

# %%
tags_df = pd.DataFrame(tags_matrix, columns = list(tags), index=list(tags))
display(tags_df)
# Out:
#           PRON      CONJ       NUM       ADV         .       DET      VERB  \
# PRON  0.006834  0.005011  0.006834  0.036902  0.041913  0.009567  0.484738
# CONJ  0.060373  0.000549  0.040615  0.057080  0.035126  0.123491  0.150384
# NUM   0.001428  0.014281  0.184220  0.003570  0.119243  0.003570  0.020707
# ADV   0.012025  0.006982  0.029868  0.081458  0.139255  0.071373  0.339022
# .     0.068769  0.060079  0.078210  0.052569  0.092372  0.172192  0.089690
# DET   0.003306  0.000431  0.022855  0.012074  0.017393  0.006037  0.040247
# VERB  0.035543  0.005433  0.022836  0.083886  0.034807  0.133610  0.167956
# PRT   0.017613  0.002348  0.056751  0.009393  0.045010  0.101370  0.401174
# ADJ   0.000194  0.016893  0.021748  0.005243  0.066019  0.005243  0.011456
# X     0.054200  0.010379  0.003075  0.025754  0.160869  0.056890  0.206419
# NOUN  0.004659  0.042454  0.009144  0.016895  0.240094  0.013106  0.149134
# ADP   0.069603  0.001012  0.063275  0.014553  0.038724  0.320931  0.008479
#
#            PRT       ADJ         X      NOUN       ADP
# PRON  0.014123  0.070615  0.088383  0.212756  0.022323
# CONJ  0.004391  0.113611  0.009330  0.349067  0.055982
# NUM   0.026062  0.035345  0.202428  0.351660  0.037487
# ADV   0.014740  0.130721  0.022886  0.032196  0.119472
# .     0.002789  0.046132  0.025641  0.218539  0.092908
# DET   0.000287  0.206411  0.045134  0.635906  0.009918
# VERB  0.030663  0.066390  0.215930  0.110589  0.092357
# PRT   0.001174  0.082975  0.012133  0.250489  0.019569
# ADJ   0.011456  0.063301  0.020971  0.696893  0.080583
# X     0.185086  0.017682  0.075726  0.061695  0.142226
# NOUN  0.043935  0.012584  0.028825  0.262344  0.176827
# ADP   0.001266  0.107062  0.034548  0.323589  0.016958

# %%
def viterbi(words, train_bag = train_words):
    state = []
    tags_unique = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in tags_unique:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = emission_prob(words[key], tag)[0]/emission_prob(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = tags_unique[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
random.seed(1234)      #define a random seed to get same sentences when run multiple times

# choose random 10 numbers
rndom = [random.randint(1,len(test_set)) for x in range(10)]

# list of 10 sents on which we test the model
test_run = [test_set[i] for i in rndom]

# list of tagged words
test_run_base = [tup for sent in test_run for tup in sent]

# list of untagged words
test_tagged_words = [tup[0] for sent in test_run for tup in sent]

# %%
tagged_seq = viterbi(test_tagged_words)

# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 

accuracy = len(check)/len(tagged_seq)
print('Viterbi Algorithm Accuracy: ',accuracy*100)
# Out:
# Viterbi Algorithm Accuracy:  93.77990430622009
